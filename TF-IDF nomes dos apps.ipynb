# %% [markdown]
# # TF-IDF

# %% [markdown]
# <p>É necessário instalar o pacote nltk para tokenizar os textos. Para fazer isso, execute por linha de comando:</p>
# <ul>
#     <li>pip install nltk</li>
#     <li>python</li>
#     <li>import nltk</li>
#     <li>nltk.download()</li>
# </ul>

# %%
import pandas as pd  # Manipulação de Dados
import nltk  # Processamento de Texto
from nltk.tokenize import word_tokenize
from collections import Counter
import numpy as np  # Arrays, Matrizes e Funções Matemáticas
from scipy.spatial import distance  # Computação Científica

# %%
# Carregando dataset (CSV) com o pandas
apps = pd.read_csv("googleplaystore.csv")
apps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# ## Exemplo da tokenização do primeiro app

# %%
word_tokenize(apps.iloc[0]['App'])
# Out:
# ['Photo', 'Editor', '&', 'Candy', 'Camera', '&', 'Grid', '&', 'ScrapBook']

# %% [markdown]
# # Calculando IDF de cada termo

# %% [markdown]
# ### Primeiro crio o vocabulário

# %%
vocabulario = Counter()
for i in range(len(apps)):
    nome_app = apps.iloc[i]['App'].lower()
    for token in word_tokenize(nome_app):
        vocabulario[token] += 1

# %%
vocabulario.most_common()
# Out:
# [('-', 1627),
#  (':', 998),
#  ('&', 979),
#  (',', 890),
#  ('for', 562),
#  ('free', 515),
#  ('app', 333),
#  (')', 321),
#  ('(', 317),
#  ('and', 283),
#  ('the', 270),
#  ('mobile', 222),
#  ('video', 198),
#  ('news', 198),
#  ('live', 194),
#  ('pro', 192),
#  ('chat', 184),
#  ('photo', 170),
#  ('by', 163),
#  ('of', 161),
#  ('!', 150),
#  ('my', 145),
#  ('–', 142),
#  ('camera', 138),
#  ('2018', 138),
#  ('dating', 134),
#  ('editor', 131),
#  ('game', 130),
#  ('theme', 129),
#  ('3d', 123),
#  ("'s", 123),
#  ('.', 120),
#  ('tv', 120),
#  ('games', 118),
#  ('learn', 111),
#  ('to', 109),
#  ('2', 108),
#  ('simulator', 107),
#  ('with', 106),
#  ('calculator', 106),
#  ('manager', 103),
#  ('tracker', 97),
#  ('hd', 96),
#  ('online', 93),
#  ('launcher', 92),
#  ('google', 92),
#  ('android', 90),
#  ('a', 87),
#  ('in', 85),
#  ('go', 83),
#  ('kids', 81),
#  ('wallpapers', 79),
#  ('english', 77),
#  ('car', 71),
#  ('wallpaper', 71),
#  ('browser', 70),
#  ('maker', 69),
#  ('sports', 68),
#  ('weather', 68),
#  ('number', 65),
#  ('keyboard', 65),
#  ('text', 64),
#  ('new', 61),
#  ('i', 60),
#  ('shopping', 60),
#  ('lite', 59),
#  ('fast', 58),
#  ('remote', 58),
#  ('at', 58),
#  ('book', 57),
#  ('file', 57),
#  ('meet', 56),
#  ('gps', 56),
#  ('real', 55),
#  ('guide', 55),
#  ('selfie', 54),
#  ('player', 54),
#  ('baby', 53),
#  ('on', 52),
#  ('color', 52),
#  ('your', 52),
#  ('call', 52),
#  ('deals', 52),
#  ('smart', 51),
#  ('racing', 49),
#  ('+', 49),
#  ('calls', 49),
#  ('3', 49),
#  ('blood', 49),
#  ('best', 48),
#  ('screen', 48),
#  ('world', 48),
#  ('dx', 48),
#  ('super', 47),
#  ('offline', 47),
#  ('ah', 47),
#  ('all', 46),
#  ('er', 46),
#  ('|', 45),
#  ('dr.', 45),
#  ('cg', 45),
#  ('test', 44),
#  ('search', 44),
#  ('cv', 44),
#  ('phone', 44),
#  ('love', 44),
#  ('plus', 44),
#  ('watch', 44),
#  ('ag', 44),
#  ('coloring', 43),
#  ('x', 43),
#  ('videos', 43),
#  ('movies', 43),
#  ('ct', 43),
#  ('db', 43),
#  ('music', 42),
#  ('messenger', 42),
#  ('banking', 42),
#  ('counter', 42),
#  ('ex', 42),
#  ('beauty', 41),
#  ('now', 41),
#  ('cm', 41),
#  ('city', 41),
#  ("'", 41),
#  ('run', 41),
#  ('scores', 41),
#  ('bg', 41),
#  ('cs', 41),
#  ('eu', 41),
#  ('florida', 41),
#  ('scanner', 40),
#  ('do', 40),
#  ('home', 40),
#  ('bd', 40),
#  ('fk', 40),
#  ('art', 39),
#  ('n', 39),
#  ('food', 39),
#  ('reader', 39),
#  ('radio', 39),
#  ('?', 39),
#  ('ap', 39),
#  ('bt', 39),
#  ('dm', 39),
#  ('dp', 39),
#  ('fe', 39),
#  ('fun', 38),
#  ('pdf', 38),
#  ('daily', 38),
#  ('calendar', 38),
#  ('p', 38),
#  ('zombie', 38),
#  ('doctor', 38),
#  ('pressure', 38),
#  ('fc', 38),
#  ('es', 37),
#  ('control', 37),
#  ('c', 37),
#  ('coupons', 37),
#  ('list', 37),
#  ('map', 37),
#  ('ac', 37),
#  ('ae', 37),
#  ('cf', 37),
#  ('dw', 37),
#  ('ec', 37),
#  ('ef', 37),
#  ('pack', 36),
#  ('dc', 36),
#  ('du', 36),
#  ('wifi', 36),
#  ('languages', 36),
#  ('ar', 36),
#  ('ce', 36),
#  ('bn', 36),
#  ('cb', 36),
#  ('cp', 36),
#  ('resume', 35),
#  ('classic', 35),
#  ('ad', 35),
#  ('full', 35),
#  ('shooter', 35),
#  ('ez', 35),
#  ('dz', 35),
#  ('official', 34),
#  ('/', 34),
#  ('time', 34),
#  ('virtual', 34),
#  ('am', 34),
#  ('bc', 34),
#  ('z', 34),
#  ('au', 34),
#  ('pixel', 33),
#  ('easy', 33),
#  ('collage', 33),
#  ('find', 33),
#  ('dictionary', 33),
#  ('facebook', 33),
#  ('pocket', 33),
#  ('sleep', 33),
#  ('heroes', 33),
#  ('fantasy', 33),
#  ('hotels', 33),
#  ('surgery', 33),
#  ('bu', 33),
#  ('download', 32),
#  ('life', 32),
#  ('block', 32),
#  ('singles', 32),
#  ('bank', 32),
#  ('planner', 32),
#  ('fitness', 32),
#  ('r', 32),
#  ('aj', 32),
#  ('bw', 32),
#  ('ci', 32),
#  ('cr', 32),
#  ('ek', 32),
#  ('ey', 32),
#  ('fl', 32),
#  ('u', 31),
#  ('buy', 31),
#  ('be', 31),
#  ('girls', 31),
#  ('b', 31),
#  ('recorder', 31),
#  ('up', 31),
#  ('1', 31),
#  ('ai', 31),
#  ('lock', 31),
#  ('workout', 31),
#  ('driving', 31),
#  ('friends', 31),
#  ('travel', 31),
#  ('ep', 31),
#  ('delivery', 30),
#  ('match', 30),
#  ('day', 30),
#  ('prep', 30),
#  ('puzzle', 30),
#  ('security', 30),
#  ('survival', 30),
#  ('war', 30),
#  ('status', 30),
#  ('ds', 30),
#  ('bk', 30),
#  ('cd', 30),
#  ('fr', 30),
#  ('training', 29),
#  ('cw', 29),
#  ('no', 29),
#  ('calorie', 29),
#  ('gun', 29),
#  ('soccer', 29),
#  ('vpn', 29),
#  ('ba', 29),
#  ('truck', 28),
#  ('maps', 28),
#  ('shop', 28),
#  ('play', 28),
#  ('emergency', 28),
#  ('downloader', 28),
#  ('flights', 28),
#  ('poker', 28),
#  ('df', 28),
#  ('fd', 28),
#  ('ideas', 27),
#  ('fashion', 27),
#  ('health', 27),
#  ('builder', 27),
#  ('dragon', 27),
#  ('people', 27),
#  ('premium', 27),
#  ('hospital', 27),
#  ('us', 27),
#  ('q', 27),
#  ('widget', 27),
#  ('de', 27),
#  ('bl', 27),
#  ('cu', 27),
#  ('dv', 27),
#  ('ev', 27),
#  ('business', 26),
#  ('design', 26),
#  ('driver', 26),
#  ('voice', 26),
#  ('sounds', 26),
#  ('sms', 26),
#  ('t', 26),
#  ('black', 26),
#  ('it', 26),
#  ('talking', 26),
#  ('bp', 26),
#  ('wi-fi', 26),
#  ('clock', 26),
#  ('ab', 26),
#  ('bf', 26),
#  ('bh', 26),
#  ('bm', 26),
#  ('bs', 26),
#  ('cx', 26),
#  ('themes', 25),
#  ('draw', 25),
#  ('cars', 25),
#  ('filter', 25),
#  ('v', 25),
#  ('mini', 25),
#  ('local', 25),
#  ('s', 25),
#  ('events', 25),
#  ('connect', 25),
#  ('fps', 25),
#  ('bz', 25),
#  ('navigation', 25),
#  ('bj', 25),
#  ('dg', 25),
#  ('dk', 25),
#  ('dt', 25),
#  ('fn', 25),
#  ('candy', 24),
#  ('manga', 24),
#  ('photos', 24),
#  ('traffic', 24),
#  ('speed', 24),
#  ('digital', 24),
#  ('recipes', 24),
#  ('read', 24),
#  ('microsoft', 24),
#  ('az', 24),
#  ('quiz', 24),
#  ('bubble', 24),
#  ('clash', 24),
#  ('angry', 24),
#  ('king', 24),
#  ('adventure', 24),
#  ('icon', 24),
#  ('cl', 24),
#  ('av', 24),
#  ('fb', 24),
#  ('ay', 24),
#  ('br', 24),
#  ('el', 24),
#  ('fh', 24),
#  ('ultimate', 23),
#  ('makeup', 23),
#  ('panda', 23),
#  ('htc', 23),
#  ('blocker', 23),
#  ('secure', 23),
#  ('funny', 23),
#  ('you', 23),
#  ('explorer', 23),
#  ('rich', 23),
#  ('house', 23),
#  ('programming', 23),
#  ('school', 23),
#  ('h', 23),
#  ('m', 23),
#  ('hunter', 23),
#  ('fp', 23),
#  ('flashlight', 23),
#  ('nights', 23),
#  ('cj', 23),
#  ('little', 22),
#  ('meter', 22),
#  ('auto', 22),
#  ('sell', 22),
#  ('weight', 22),
#  ('comics', 22),
#  ('web', 22),
#  ('private', 22),
#  ('emoji', 22),
#  ('stream', 22),
#  ('pet', 22),
#  ('math', 22),
#  ('flashcards', 22),
#  ('more', 22),
#  ('info', 22),
#  ('money', 22),
#  ('4', 22),
#  ('finder', 22),
#  ('estate', 22),
#  ('family', 22),
#  ('[', 22),
#  (']', 22),
#  ('birds', 22),
#  ('battle', 22),
#  ('notes', 22),
#  ('quran', 22),
#  ('apps', 21),
#  ('practice', 21),
#  ('edition', 21),
#  ('me', 21),
#  ('service', 21),
#  ('space', 21),
#  ('scan', 21),
#  ('simple', 21),
#  ('story', 21),
#  ('whatsapp', 21),
#  ('galaxy', 21),
#  ('cam', 21),
#  ('code', 21),
#  ('football', 21),
#  ('face', 21),
#  ('monitor', 21),
#  ('shooting', 21),
#  ('2017', 21),
#  ('booster', 21),
#  ('al', 21),
#  ('texas', 21),
#  ('eo', 21),
#  ('card', 20),
#  ('parking', 20),
#  ('step', 20),
#  ('books', 20),
#  ('ringtones', 20),
#  ('mail', 20),
#  ('gold', 20),
#  ('top', 20),
#  ('network', 20),
#  ('trainer', 20),
#  ('bike', 20),
#  ('club', 20),
#  ('style', 20),
#  ('saga', 20),
#  ('royale', 20),
#  ('jump', 20),
#  ('sniper', 20),
#  ('wars', 20),
#  ('vr', 20),
#  ('ca', 20),
#  ('axe', 20),
#  ('lottery', 20),
#  ('bv', 20),
#  ('ck', 20),
#  ('dn', 20),
#  ('eb', 20),
#  ('ei', 20),
#  ('offroad', 19),
#  ('white', 19),
#  ('care', 19),
#  ('stories', 19),
#  ('cloud', 19),
#  ('caller', 19),
#  ('job', 19),
#  ('master', 19),
#  ('viewer', 19),
#  ('id', 19),
#  ('’', 19),
#  ('market', 19),
#  ('credit', 19),
#  ('5', 19),
#  ('results', 19),
#  ('co', 19),
#  ('word', 19),
#  ('quest', 19),
#  ('hero', 19),
#  ('golf', 19),
#  ('anatomy', 19),
#  ('stats', 19),
#  ('to-do', 19),
#  ('sim', 19),
#  ('eg', 19),
#  ('room', 18),
#  ('how', 18),
#  ('bear', 18),
#  ('tips', 18),
#  ('ads', 18),
#  ('ball', 18),
#  ('date', 18),
#  ('times', 18),
#  ('magic', 18),
#  ('challenge', 18),
#  ('diet', 18),
#  ('meditation', 18),
#  ('samsung', 18),
#  ('background', 18),
#  ('cards', 18),
#  ('attack', 18),
#  ('strike', 18),
#  ('guns', 18),
#  ('rpg', 18),
#  ('forecast', 18),
#  ('antivirus', 18),
#  ('ak', 18),
#  ('fo', 18),
#  ('sandbox', 17),
#  ('trucks', 17),
#  ('detector', 17),
#  ('log', 17),
#  ('#', 17),
#  ('social', 17),
#  ('zombies', 17),
#  ('brain', 17),
#  ('learning', 17),
#  ('e', 17),
#  ('union', 17),
#  ('rent', 17),
#  ('shoot', 17),
#  ('advanced', 17),
#  ('hotel', 17),
#  ('cleaner', 17),
#  ('o', 17),
#  ('five', 17),
#  ('aw', 17),
#  ('bi', 17),
#  ('bx', 17),
#  ('morse', 17),
#  ('tickets', 16),
#  ('exam', 16),
#  ('from', 16),
#  ('lg', 16),
#  ('—', 16),
#  ('line', 16),
#  ('messages', 16),
#  ('flirt', 16),
#  ('prank', 16),
#  ('words', 16),
#  ('youtube', 16),
#  ('shows', 16),
#  ('episodes', 16),
#  ('k', 16),
#  ('pay', 16),
#  ('one', 16),
#  ('breaking', 16),
#  ('abs', 16),
#  ('running', 16),
#  ('workouts', 16),
#  ('yoga', 16),
#  ('sound', 16),
#  ('latest', 16),
#  ('rental', 16),
#  ('as', 16),
#  ('crush', 16),
#  ('dash', 16),
#  ('moto', 16),
#  ('masha', 16),
#  ('chess', 16),
#  ('assistant', 16),
#  ('instagram', 16),
#  ('rewards', 16),
#  ('view', 16),
#  ('battery', 16),
#  ('santa', 16),
#  ('fans', 16),
#  ('casino', 16),
#  ('et', 16),
#  ('cy', 16),
#  ('backgrounds', 15),
#  ('creator', 15),
#  ('princess', 15),
#  ('radar', 15),
#  ('first', 15),
#  ('yahoo', 15),
#  ('dialer', 15),
#  ('heart', 15),
#  ('cooking', 15),
#  ('data', 15),
#  ('relax', 15),
#  ('diary', 15),
#  ('action', 15),
#  ('puzzles', 15),
#  ('crime', 15),
#  ('alerts', 15),
#  ('light', 15),
#  ('tool', 15),
#  ('emulator', 15),
#  ('barcelona', 15),
#  ('bo', 15),
#  ('sale', 14),
#  ('race', 14),
#  ('report', 14),
#  ('30', 14),
#  ('out', 14),
#  ('academy', 14),
#  ('fox', 14),
#  ('reminder', 14),
#  ('songs', 14),
#  ('transfer', 14),
#  ('made', 14),
#  ('alarm', 14),
#  ('dark', 14),
#  ('w', 14),
#  ('bill', 14),
#  ('subway', 14),
#  ('hill', 14),
#  ('tom', 14),
#  ('evolution', 14),
#  ('bus', 14),
#  ('companion', 14),
#  ('share', 14),
#  ('drive', 14),
#  ('changer', 14),
#  ('led', 14),
#  ('locker', 14),
#  ('applock', 14),
#  ('j', 14),
#  ('audio', 14),
#  ('egg', 14),
#  ('ax', 14),
#  ('em', 14),
#  ('bq', 14),
#  ('volvo', 14),
#  ('focus', 13),
#  ('diy', 13),
#  ('anime', 13),
#  ('craft', 13),
#  ('used', 13),
#  ('language', 13),
#  ('sugar', 13),
#  ('league', 13),
#  ('get', 13),
#  ('dj', 13),
#  ('quotes', 13),
#  ('night', 13),
#  ('la', 13),
#  ('courses', 13),
#  ('cbs', 13),
#  ('better', 13),
#  ('7', 13),
#  ('journal', 13),
#  ('blast', 13),
#  ('legends', 13),
#  ('star', 13),
#  ('pony', 13),
#  ('diabetes', 13),
#  ('train', 13),
#  ('gif', 13),
#  ('coupon', 13),
#  ('gallery', 13),
#  ('flight', 13),
#  ('note', 13),
#  ('notepad', 13),
#  ('l', 13),
#  ('modern', 13),
#  ('ak-47', 13),
#  ('cruiser', 13),
#  ('toyota', 13),
#  ('paint', 12),
#  ('pages', 12),
#  ('cat', 12),
#  ('monster', 12),
#  ('police', 12),
#  ('sweet', 12),
#  ('store', 12),
#  ('days', 12),
#  ('center', 12),
#  ('box', 12),
#  ('beta', 12),
#  ('contacts', 12),
#  ('privacy', 12),
#  ('next', 12),
#  ('blue', 12),
#  ('gay', 12),
#  ('random', 12),
#  ('talk', 12),
#  ('dog', 12),
#  ('movie', 12),
#  ('animal', 12),
#  ('an', 12),
#  ('cash', 12),
#  ('wallet', 12),
#  ('personal', 12),
#  ('burger', 12),
#  ('coach', 12),
#  ('period', 12),
#  ('therapy', 12),
#  ('apartment', 12),
#  ('buddy', 12),
#  ('pop', 12),
#  ('cute', 12),
#  ('street', 12),
#  ('town', 12),
#  ('open', 12),
#  ('profile', 12),
#  ('image', 12),
#  ('tennis', 12),
#  ('sense', 12),
#  ('taxi', 12),
#  ('kpop', 12),
#  ('transit', 12),
#  ('air', 12),
#  ('af', 12),
#  ('tools', 12),
#  ('co-op', 12),
#  ('aq', 12),
#  ('cq', 12),
#  ('fa', 12),
#  ('fg', 12),
#  ('filters', 11),
#  ('4k', 11),
#  ('tutorial', 11),
#  ('make', 11),
#  ('2019', 11),
#  ('navigator', 11),
#  ('check', 11),
#  ('park', 11),
#  ('application', 11),
#  ('sharing', 11),
#  ('sticker', 11),
#  ('translator', 11),
#  ('help', 11),
#  ('office', 11),
#  ('or', 11),
#  ('quick', 11),
#  ('y', 11),
#  ('marvel', 11),
#  ('unlimited', 11),
#  ('high', 11),
#  ('adult', 11),
#  ('abc', 11),
#  ('red', 11),
#  ('track', 11),
#  ('score', 11),
#  ('bitcoin', 11),
#  ('kitchen', 11),
#  ('order', 11),
#  ('restaurant', 11),
#  ('loss', 11),
#  ('hair', 11),
#  ('community', 11),
#  ('studio', 11),
#  ('effects', 11),
#  ('song', 11),
#  ('legend', 11),
#  ('road', 11),
#  ('dino', 11),
#  ('power', 11),
#  ('simulation', 11),
#  ('amino', 11),
#  ('blur', 11),
#  ('espn', 11),
#  ('organizer', 11),
#  ('hotspot', 11),
#  ('beach', 11),
#  ('task', 11),
#  ('today', 11),
#  ('financial', 11),
#  ('root', 11),
#  ('f', 11),
#  ('2016', 11),
#  ('grand', 11),
#  ('intelligence', 11),
#  ('access', 11),
#  ('a-z', 11),
#  ('ham', 11),
#  ('explained', 11),
#  ('eh', 11),
#  ('effect', 10),
#  ('cartoon', 10),
#  ('extreme', 10),
#  ('messaging', 10),
#  ('amazon', 10),
#  ('spanish', 10),
#  ('point', 10),
#  ('email', 10),
#  ('who', 10),
#  ('safe', 10),
#  ('multiplayer', 10),
#  ('educational', 10),
#  ('pictures', 10),
#  ('summer', 10),
#  ('india', 10),
#  ('fm', 10),
#  ('save', 10),
#  ('stock', 10),
#  ('internet', 10),
#  ('grocery', 10),
#  ('minute', 10),
#  ('anywhere', 10),
#  ('pregnancy', 10),
#  ('water', 10),
#  ('rentals', 10),
#  ('library', 10),
#  ('converter', 10),
#  ('mp3', 10),
#  ('8', 10),
#  ('pool', 10),
#  ('rope', 10),
#  ('fire', 10),
#  ('interactive', 10),
#  ('dungeon', 10),
#  ('fight', 10),
#  ('like', 10),
#  ('touch', 10),
#  ('legacy', 10),
#  ('board', 10),
#  ('we', 10),
#  ('qr', 10),
#  ('european', 10),
#  ('input', 10),
#  ("n't", 10),
#  ('g', 10),
#  ('stickman', 10),
#  ('craigslist', 10),
#  ('san', 10),
#  ('blackjack', 10),
#  ('artificial', 10),
#  ('assault', 10),
#  ('tests', 10),
#  ('defense', 10),
#  ('en', 10),
#  ('dr', 10),
#  ('holdem', 10),
#  ('ch', 10),
#  ('tn', 10),
#  ('cz', 10),
#  ('pistol', 10),
#  ('charging', 10),
#  ('ew', 10),
#  ('fj', 10),
#  ('hide', 9),
#  ('drawing', 9),
#  ('name', 9),
#  ('images', 9),
#  ('net', 9),
#  ('state', 9),
#  ('information', 9),
#  ('dmv', 9),
#  ('permit', 9),
#  ('discount', 9),
#  ('mirror', 9),
#  ('complete', 9),
#  ('medicine', 9),
#  ('manual', 9),
#  ('docs', 9),
#  ('plugin', 9),
#  ('meetings', 9),
#  ('tiny', 9),
#  ('accounting', 9),
#  ('tracking', 9),
#  ('professional', 9),
#  ('comic', 9),
#  ('perfect', 9),
#  ('chrome', 9),
#  ('telegram', 9),
#  ('hot', 9),
#  ('not', 9),
#  ('elite', 9),
#  ('just', 9),
#  ('numbers', 9),
#  ('girl', 9),
#  ('group', 9),
#  ('chinese', 9),
#  ('·', 9),
#  ('vocabulary', 9),
#  ('speak', 9),
#  ('study', 9),
#  ('generator', 9),
#  ('channel', 9),
#  ('history', 9),
#  ('budget', 9),
#  ('recipe', 9),
#  ('restaurants', 9),
#  ('walk', 9),
#  ('body', 9),
#  ('ovulation', 9),
#  ('noise', 9),
#  ('public', 9),
#  ('android™', 9),
#  ('roblox', 9),
#  ('temple', 9),
#  ('plants', 9),
#  ('vs.', 9),
#  ('tiles', 9),
#  ('rush', 9),
#  ('fruit', 9),
#  ('piano', 9),
#  ('cube', 9),
#  ('empire', 9),
#  ('force', 9),
#  ('mlb', 9),
#  ('ice', 9),
#  ('strategy', 9),
#  ('jigsaw', 9),
#  ('off', 9),
#  ('rescue', 9),
#  ('crazy', 9),
#  ('jam', 9),
#  ('human', 9),
#  ('back', 9),
#  ('adobe', 9),
#  ('mx', 9),
#  ('sport', 9),
#  ('highlights', 9),
#  ('where', 9),
#  ('neon', 9),
#  ('widgets', 9),
#  ('tech', 9),
#  ('podcast', 9),
#  ('bible', 9),
#  ('commando', 9),
#  ('add-on', 9),
#  ('wizard', 9),
#  ('9.0', 9),
#  ('freddy', 9),
#  ('andreas', 9),
#  ('rifle', 9),
#  ('templates', 9),
#  ('bluetooth', 9),
#  ('church', 9),
#  ('dh', 9),
#  ('write', 8),
#  ('men', 8),
#  ('disney', 8),
#  ('american', 8),
#  ('speedometer', 8),
#  ('discover', 8),
#  ('women', 8),
#  ('jobs', 8),
#  ('services', 8),
#  ('square', 8),
#  ('express', 8),
#  ('original', 8),
#  ('children', 8),
#  ('can', 8),
#  ('streaming', 8),
#  ('opera', 8),
#  ('notifier', 8),
#  ('rooms', 8),
#  ('lyrics', 8),
#  ('preschool', 8),
#  ('checker', 8),
#  ('toca', 8),
#  ('motorola', 8),
#  ('dance', 8),
#  ('champions', 8),
#  ('bbc', 8),
#  ('entertainment', 8),
#  ('show', 8),
#  ('demand', 8),
#  ('series', 8),
#  ('sonic', 8),
#  ('t-mobile', 8),
#  ('booking', 8),
#  ('lose', 8),
#  ('fat', 8),
#  ('cycling', 8),
#  ('walking', 8),
#  ('chest', 8),
#  ('plans', 8),
#  ('10', 8),
#  ('apartments', 8),
#  ('homes', 8),
#  ('beautiful', 8),
#  ('ruler', 8),
#  ('decorating', 8),
#  ('island', 8),
#  ('wall', 8),
#  ('stickers', 8),
#  ('helper', 8),
#  ('barcode', 8),
#  ('big', 8),
#  ('solitaire', 8),
#  ('salon', 8),
#  ('kick', 8),
#  ('climb', 8),
#  ('farm', 8),
#  ('toy', 8),
#  ('vs', 8),
#  ('stars', 8),
#  ('castle', 8),
#  ('earth', 8),
#  ('dead', 8),
#  ('jewels', 8),
#  ('turbo', 8),
#  ('4x4', 8),
#  ('build', 8),
#  ('global', 8),
#  ('motocross', 8),
#  ('medical', 8),
#  ('mega', 8),
#  ('drug', 8),
#  ('hearing', 8),
#  ('lab', 8),
#  ('discounts', 8),
#  ('magazine', 8),
#  ('ultra', 8),
#  ('airlines', 8),
#  ('files', 8),
#  ('backup', 8),
#  ('killer', 8),
#  ('what', 8),
#  ('slots', 8),
#  ('bar', 8),
#  ('fcu', 8),
#  ('land', 8),
#  ('analog', 8),
#  ('saver', 8),
#  ('gate', 8),
#  ('bacterial', 8),
#  ('vaginosis', 8),
#  ('thailand', 8),
#  ("hold'em", 8),
#  ('dy', 8),
#  ('tneb', 8),
#  ('cool', 7),
#  ('garden', 7),
#  ('pink', 7),
#  ...]

# %%
len(vocabulario)
# Out:
# 9545

# %% [markdown]
# ### Agora cálculo do IDF

# %%
numero_documentos_termo = Counter()
for i in range(len(apps)):
    nome_app = apps.iloc[i]['App'].lower()
    termos = list(set(word_tokenize(nome_app)))
    for termo in termos:
        numero_documentos_termo[termo] += 1

# %%
# Podemos obter o numero de documentos em que cada token aparece (independente do número de vezes)
numero_documentos_termo["soccer"]
# Out:
# 28

# %%
numero_documentos_termo.most_common()
# Out:
# [('-', 1605),
#  (':', 997),
#  ('&', 960),
#  (',', 559),
#  ('for', 551),
#  ('free', 504),
#  ('app', 327),
#  (')', 319),
#  ('(', 315),
#  ('and', 278),
#  ('the', 262),
#  ('mobile', 222),
#  ('live', 192),
#  ('pro', 192),
#  ('video', 185),
#  ('news', 183),
#  ('chat', 169),
#  ('photo', 164),
#  ('by', 162),
#  ('of', 158),
#  ('my', 145),
#  ('–', 142),
#  ('!', 140),
#  ('2018', 138),
#  ('dating', 134),
#  ('game', 130),
#  ('camera', 128),
#  ('editor', 128),
#  ('theme', 128),
#  ("'s", 122),
#  ('3d', 121),
#  ('games', 117),
#  ('tv', 111),
#  ('learn', 109),
#  ('2', 108),
#  ('to', 107),
#  ('simulator', 107),
#  ('with', 106),
#  ('manager', 103),
#  ('calculator', 100),
#  ('.', 97),
#  ('hd', 96),
#  ('tracker', 94),
#  ('online', 93),
#  ('google', 92),
#  ('android', 90),
#  ('launcher', 84),
#  ('in', 84),
#  ('go', 81),
#  ('wallpapers', 79),
#  ('a', 79),
#  ('kids', 75),
#  ('english', 72),
#  ('wallpaper', 69),
#  ('browser', 68),
#  ('sports', 68),
#  ('car', 66),
#  ('maker', 63),
#  ('weather', 63),
#  ('text', 61),
#  ('new', 61),
#  ('keyboard', 60),
#  ('i', 60),
#  ('number', 59),
#  ('shopping', 59),
#  ('lite', 58),
#  ('fast', 58),
#  ('at', 58),
#  ('meet', 56),
#  ('book', 55),
#  ('real', 55),
#  ('remote', 55),
#  ('gps', 55),
#  ('guide', 54),
#  ('selfie', 53),
#  ('on', 52),
#  ('your', 52),
#  ('deals', 52),
#  ('color', 51),
#  ('smart', 51),
#  ('call', 50),
#  ('baby', 50),
#  ('+', 49),
#  ('calls', 49),
#  ('blood', 49),
#  ('racing', 48),
#  ('best', 48),
#  ('player', 48),
#  ('world', 48),
#  ('offline', 47),
#  ('screen', 47),
#  ('3', 47),
#  ('ah', 47),
#  ('file', 47),
#  ('all', 45),
#  ('dr.', 45),
#  ('dx', 45),
#  ('cg', 45),
#  ('er', 45),
#  ('search', 44),
#  ('super', 44),
#  ('phone', 44),
#  ('love', 44),
#  ('x', 43),
#  ('videos', 43),
#  ('plus', 43),
#  ('movies', 43),
#  ('watch', 43),
#  ('ct', 43),
#  ('ag', 43),
#  ('coloring', 42),
#  ('test', 42),
#  ('banking', 42),
#  ('ex', 42),
#  ('db', 42),
#  ('now', 41),
#  ('cv', 41),
#  ('messenger', 41),
#  ('cm', 41),
#  ('scores', 41),
#  ('bg', 41),
#  ('eu', 41),
#  ('florida', 41),
#  ('music', 40),
#  ('beauty', 40),
#  ('city', 40),
#  ('do', 40),
#  ('counter', 40),
#  ('bd', 40),
#  ('cs', 40),
#  ('fk', 40),
#  ('n', 39),
#  ('food', 39),
#  ('reader', 39),
#  ('radio', 39),
#  ('?', 39),
#  ('home', 39),
#  ('ap', 39),
#  ('bt', 39),
#  ('dm', 39),
#  ('fe', 39),
#  ('art', 38),
#  ('fun', 38),
#  ('daily', 38),
#  ('zombie', 38),
#  ('doctor', 38),
#  ('pressure', 38),
#  ('fc', 38),
#  ('dp', 38),
#  ('es', 37),
#  ('calendar', 37),
#  ("'", 37),
#  ('coupons', 37),
#  ('ac', 37),
#  ('ae', 37),
#  ('cf', 37),
#  ('dw', 37),
#  ('ec', 37),
#  ('ef', 37),
#  ('pack', 36),
#  ('|', 36),
#  ('pdf', 36),
#  ('dc', 36),
#  ('du', 36),
#  ('control', 36),
#  ('languages', 36),
#  ('list', 36),
#  ('run', 36),
#  ('p', 36),
#  ('ar', 36),
#  ('ce', 36),
#  ('bn', 36),
#  ('cp', 36),
#  ('classic', 35),
#  ('full', 35),
#  ('wifi', 35),
#  ('c', 35),
#  ('shooter', 35),
#  ('ez', 35),
#  ('dz', 35),
#  ('official', 34),
#  ('scanner', 34),
#  ('ad', 34),
#  ('virtual', 34),
#  ('map', 34),
#  ('am', 34),
#  ('bc', 34),
#  ('cb', 34),
#  ('pixel', 33),
#  ('easy', 33),
#  ('find', 33),
#  ('facebook', 33),
#  ('pocket', 33),
#  ('heroes', 33),
#  ('z', 33),
#  ('hotels', 33),
#  ('au', 33),
#  ('bu', 33),
#  ('download', 32),
#  ('dictionary', 32),
#  ('resume', 32),
#  ('life', 32),
#  ('block', 32),
#  ('singles', 32),
#  ('planner', 32),
#  ('fitness', 32),
#  ('r', 32),
#  ('surgery', 32),
#  ('bw', 32),
#  ('ci', 32),
#  ('cr', 32),
#  ('ek', 32),
#  ('ey', 32),
#  ('fl', 32),
#  ('u', 31),
#  ('collage', 31),
#  ('buy', 31),
#  ('be', 31),
#  ('girls', 31),
#  ('b', 31),
#  ('time', 31),
#  ('up', 31),
#  ('1', 31),
#  ('bank', 31),
#  ('driving', 31),
#  ('friends', 31),
#  ('aj', 31),
#  ('ep', 31),
#  ('match', 30),
#  ('day', 30),
#  ('ai', 30),
#  ('prep', 30),
#  ('lock', 30),
#  ('puzzle', 30),
#  ('security', 30),
#  ('survival', 30),
#  ('war', 30),
#  ('travel', 30),
#  ('ds', 30),
#  ('bk', 30),
#  ('cd', 30),
#  ('fr', 30),
#  ('training', 29),
#  ('cw', 29),
#  ('no', 29),
#  ('workout', 29),
#  ('calorie', 29),
#  ('maps', 28),
#  ('shop', 28),
#  ('recorder', 28),
#  ('sleep', 28),
#  ('gun', 28),
#  ('soccer', 28),
#  ('fantasy', 28),
#  ('emergency', 28),
#  ('downloader', 28),
#  ('flights', 28),
#  ('ba', 28),
#  ('df', 28),
#  ('fd', 28),
#  ('ideas', 27),
#  ('fashion', 27),
#  ('truck', 27),
#  ('/', 27),
#  ('health', 27),
#  ('play', 27),
#  ('builder', 27),
#  ('delivery', 27),
#  ('people', 27),
#  ('premium', 27),
#  ('hospital', 27),
#  ('us', 27),
#  ('q', 27),
#  ('widget', 27),
#  ('status', 27),
#  ('poker', 27),
#  ('de', 27),
#  ('bl', 27),
#  ('cu', 27),
#  ('dv', 27),
#  ('ev', 27),
#  ('business', 26),
#  ('design', 26),
#  ('voice', 26),
#  ('sounds', 26),
#  ('sms', 26),
#  ('dragon', 26),
#  ('black', 26),
#  ('it', 26),
#  ('talking', 26),
#  ('bp', 26),
#  ('wi-fi', 26),
#  ('bf', 26),
#  ('bh', 26),
#  ('bm', 26),
#  ('bs', 26),
#  ('draw', 25),
#  ('cars', 25),
#  ('driver', 25),
#  ('filter', 25),
#  ('v', 25),
#  ('mini', 25),
#  ('local', 25),
#  ('s', 25),
#  ('events', 25),
#  ('connect', 25),
#  ('fps', 25),
#  ('bz', 25),
#  ('navigation', 25),
#  ('clock', 25),
#  ('ab', 25),
#  ('bj', 25),
#  ('cx', 25),
#  ('dg', 25),
#  ('dk', 25),
#  ('dt', 25),
#  ('fn', 25),
#  ('candy', 24),
#  ('themes', 24),
#  ('photos', 24),
#  ('digital', 24),
#  ('microsoft', 24),
#  ('az', 24),
#  ('t', 24),
#  ('quiz', 24),
#  ('clash', 24),
#  ('angry', 24),
#  ('king', 24),
#  ('adventure', 24),
#  ('vpn', 24),
#  ('icon', 24),
#  ('cl', 24),
#  ('av', 24),
#  ('ay', 24),
#  ('br', 24),
#  ('el', 24),
#  ('fh', 24),
#  ('ultimate', 23),
#  ('recipes', 23),
#  ('read', 23),
#  ('panda', 23),
#  ('htc', 23),
#  ('secure', 23),
#  ('funny', 23),
#  ('you', 23),
#  ('explorer', 23),
#  ('rich', 23),
#  ('programming', 23),
#  ('school', 23),
#  ('h', 23),
#  ('bubble', 23),
#  ('hunter', 23),
#  ('fp', 23),
#  ('nights', 23),
#  ('fb', 23),
#  ('cj', 23),
#  ('little', 22),
#  ('traffic', 22),
#  ('sell', 22),
#  ('weight', 22),
#  ('blocker', 22),
#  ('comics', 22),
#  ('private', 22),
#  ('stream', 22),
#  ('pet', 22),
#  ('flashcards', 22),
#  ('more', 22),
#  ('info', 22),
#  ('money', 22),
#  ('4', 22),
#  ('finder', 22),
#  ('m', 22),
#  ('estate', 22),
#  ('family', 22),
#  ('[', 22),
#  (']', 22),
#  ('birds', 22),
#  ('battle', 22),
#  ('notes', 22),
#  ('flashlight', 22),
#  ('apps', 21),
#  ('edition', 21),
#  ('practice', 21),
#  ('auto', 21),
#  ('me', 21),
#  ('speed', 21),
#  ('service', 21),
#  ('makeup', 21),
#  ('space', 21),
#  ('scan', 21),
#  ('simple', 21),
#  ('story', 21),
#  ('web', 21),
#  ('whatsapp', 21),
#  ('emoji', 21),
#  ('galaxy', 21),
#  ('cam', 21),
#  ('math', 21),
#  ('code', 21),
#  ('football', 21),
#  ('monitor', 21),
#  ('shooting', 21),
#  ('2017', 21),
#  ('quran', 21),
#  ('eo', 21),
#  ('card', 20),
#  ('meter', 20),
#  ('books', 20),
#  ('ringtones', 20),
#  ('gold', 20),
#  ('top', 20),
#  ('network', 20),
#  ('face', 20),
#  ('club', 20),
#  ('style', 20),
#  ('saga', 20),
#  ('jump', 20),
#  ('sniper', 20),
#  ('wars', 20),
#  ('ca', 20),
#  ('al', 20),
#  ('lottery', 20),
#  ('texas', 20),
#  ('bv', 20),
#  ('ck', 20),
#  ('dn', 20),
#  ('eb', 20),
#  ('ei', 20),
#  ('offroad', 19),
#  ('white', 19),
#  ('care', 19),
#  ('stories', 19),
#  ('cloud', 19),
#  ('master', 19),
#  ('viewer', 19),
#  ('mail', 19),
#  ('id', 19),
#  ('house', 19),
#  ('’', 19),
#  ('market', 19),
#  ('credit', 19),
#  ('5', 19),
#  ('trainer', 19),
#  ('bike', 19),
#  ('results', 19),
#  ('co', 19),
#  ('word', 19),
#  ('quest', 19),
#  ('hero', 19),
#  ('anatomy', 19),
#  ('stats', 19),
#  ('vr', 19),
#  ('to-do', 19),
#  ('sim', 19),
#  ('axe', 19),
#  ('eg', 19),
#  ('room', 18),
#  ('manga', 18),
#  ('how', 18),
#  ('bear', 18),
#  ('caller', 18),
#  ('ads', 18),
#  ('times', 18),
#  ('magic', 18),
#  ('challenge', 18),
#  ('meditation', 18),
#  ('samsung', 18),
#  ('cards', 18),
#  ('royale', 18),
#  ('attack', 18),
#  ('strike', 18),
#  ('guns', 18),
#  ('rpg', 18),
#  ('forecast', 18),
#  ('antivirus', 18),
#  ('ak', 18),
#  ('sandbox', 17),
#  ('trucks', 17),
#  ('detector', 17),
#  ('log', 17),
#  ('ball', 17),
#  ('date', 17),
#  ('#', 17),
#  ('social', 17),
#  ('zombies', 17),
#  ('brain', 17),
#  ('learning', 17),
#  ('e', 17),
#  ('union', 17),
#  ('diet', 17),
#  ('rent', 17),
#  ('shoot', 17),
#  ('advanced', 17),
#  ('hotel', 17),
#  ('booster', 17),
#  ('five', 17),
#  ('aw', 17),
#  ('bi', 17),
#  ('bx', 17),
#  ('fo', 17),
#  ('exam', 16),
#  ('from', 16),
#  ('tickets', 16),
#  ('parking', 16),
#  ('tips', 16),
#  ('—', 16),
#  ('line', 16),
#  ('messages', 16),
#  ('flirt', 16),
#  ('prank', 16),
#  ('words', 16),
#  ('youtube', 16),
#  ('shows', 16),
#  ('episodes', 16),
#  ('k', 16),
#  ('pay', 16),
#  ('breaking', 16),
#  ('running', 16),
#  ('workouts', 16),
#  ('sound', 16),
#  ('latest', 16),
#  ('rental', 16),
#  ('as', 16),
#  ('background', 16),
#  ('crush', 16),
#  ('dash', 16),
#  ('golf', 16),
#  ('masha', 16),
#  ('chess', 16),
#  ('assistant', 16),
#  ('instagram', 16),
#  ('rewards', 16),
#  ('view', 16),
#  ('cleaner', 16),
#  ('santa', 16),
#  ('fans', 16),
#  ('casino', 16),
#  ('et', 16),
#  ('morse', 16),
#  ('cy', 16),
#  ('backgrounds', 15),
#  ('creator', 15),
#  ('princess', 15),
#  ('radar', 15),
#  ('first', 15),
#  ('job', 15),
#  ('lg', 15),
#  ('yahoo', 15),
#  ('dialer', 15),
#  ('heart', 15),
#  ('cooking', 15),
#  ('one', 15),
#  ('data', 15),
#  ('abs', 15),
#  ('relax', 15),
#  ('diary', 15),
#  ('moto', 15),
#  ('action', 15),
#  ('puzzles', 15),
#  ('alerts', 15),
#  ('light', 15),
#  ('tool', 15),
#  ('o', 15),
#  ('emulator', 15),
#  ('barcelona', 15),
#  ('bo', 15),
#  ('sale', 14),
#  ('race', 14),
#  ('report', 14),
#  ('step', 14),
#  ('30', 14),
#  ('out', 14),
#  ('academy', 14),
#  ('fox', 14),
#  ('reminder', 14),
#  ('songs', 14),
#  ('transfer', 14),
#  ('made', 14),
#  ('alarm', 14),
#  ('dark', 14),
#  ('w', 14),
#  ('hill', 14),
#  ('tom', 14),
#  ('evolution', 14),
#  ('bus', 14),
#  ('companion', 14),
#  ('share', 14),
#  ('drive', 14),
#  ('changer', 14),
#  ('led', 14),
#  ('applock', 14),
#  ('j', 14),
#  ('audio', 14),
#  ('ax', 14),
#  ('em', 14),
#  ('bq', 14),
#  ('volvo', 14),
#  ('focus', 13),
#  ('diy', 13),
#  ('anime', 13),
#  ('craft', 13),
#  ('language', 13),
#  ('league', 13),
#  ('get', 13),
#  ('quotes', 13),
#  ('night', 13),
#  ('la', 13),
#  ('courses', 13),
#  ('cbs', 13),
#  ('better', 13),
#  ('7', 13),
#  ('journal', 13),
#  ('bill', 13),
#  ('subway', 13),
#  ('blast', 13),
#  ('legends', 13),
#  ('star', 13),
#  ('crime', 13),
#  ('pony', 13),
#  ('diabetes', 13),
#  ('train', 13),
#  ('coupon', 13),
#  ('gallery', 13),
#  ('flight', 13),
#  ('locker', 13),
#  ('battery', 13),
#  ('note', 13),
#  ('notepad', 13),
#  ('l', 13),
#  ('modern', 13),
#  ('ak-47', 13),
#  ('egg', 13),
#  ('cruiser', 13),
#  ('toyota', 13),
#  ('paint', 12),
#  ('pages', 12),
#  ('cat', 12),
#  ('monster', 12),
#  ('police', 12),
#  ('sweet', 12),
#  ('store', 12),
#  ('days', 12),
#  ('center', 12),
#  ('box', 12),
#  ('beta', 12),
#  ('contacts', 12),
#  ('privacy', 12),
#  ('next', 12),
#  ('blue', 12),
#  ('sugar', 12),
#  ('random', 12),
#  ('talk', 12),
#  ('movie', 12),
#  ('animal', 12),
#  ('an', 12),
#  ('cash', 12),
#  ('wallet', 12),
#  ('personal', 12),
#  ('burger', 12),
#  ('coach', 12),
#  ('yoga', 12),
#  ('therapy', 12),
#  ('buddy', 12),
#  ('pop', 12),
#  ('cute', 12),
#  ('street', 12),
#  ('town', 12),
#  ('open', 12),
#  ('image', 12),
#  ('sense', 12),
#  ('kpop', 12),
#  ('air', 12),
#  ('af', 12),
#  ('tools', 12),
#  ('co-op', 12),
#  ('aq', 12),
#  ('cq', 12),
#  ('fa', 12),
#  ('fg', 12),
#  ('filters', 11),
#  ('4k', 11),
#  ('tutorial', 11),
#  ('make', 11),
#  ('2019', 11),
#  ('used', 11),
#  ('navigator', 11),
#  ('check', 11),
#  ('application', 11),
#  ('sharing', 11),
#  ('sticker', 11),
#  ('translator', 11),
#  ('help', 11),
#  ('office', 11),
#  ('or', 11),
#  ('quick', 11),
#  ('y', 11),
#  ('marvel', 11),
#  ('unlimited', 11),
#  ('high', 11),
#  ('adult', 11),
#  ('dj', 11),
#  ('abc', 11),
#  ('red', 11),
#  ('track', 11),
#  ('score', 11),
#  ('bitcoin', 11),
#  ('kitchen', 11),
#  ('order', 11),
#  ('restaurant', 11),
#  ('loss', 11),
#  ('community', 11),
#  ('studio', 11),
#  ('apartment', 11),
#  ('effects', 11),
#  ('song', 11),
#  ('legend', 11),
#  ('road', 11),
#  ('dino', 11),
#  ('power', 11),
#  ('simulation', 11),
#  ('profile', 11),
#  ('amino', 11),
#  ('espn', 11),
#  ('tennis', 11),
#  ('organizer', 11),
#  ('hotspot', 11),
#  ('beach', 11),
#  ('today', 11),
#  ('taxi', 11),
#  ('financial', 11),
#  ('root', 11),
#  ('f', 11),
#  ('2016', 11),
#  ('grand', 11),
#  ('intelligence', 11),
#  ('access', 11),
#  ('a-z', 11),
#  ('ham', 11),
#  ('explained', 11),
#  ('eh', 11),
#  ('cartoon', 10),
#  ('extreme', 10),
#  ('messaging', 10),
#  ('park', 10),
#  ('amazon', 10),
#  ('spanish', 10),
#  ('point', 10),
#  ('email', 10),
#  ('who', 10),
#  ('safe', 10),
#  ('multiplayer', 10),
#  ('educational', 10),
#  ('pictures', 10),
#  ('summer', 10),
#  ('india', 10),
#  ('fm', 10),
#  ('save', 10),
#  ('internet', 10),
#  ('grocery', 10),
#  ('hair', 10),
#  ('minute', 10),
#  ('anywhere', 10),
#  ('pregnancy', 10),
#  ('period', 10),
#  ('water', 10),
#  ('rentals', 10),
#  ('library', 10),
#  ('converter', 10),
#  ('mp3', 10),
#  ('pool', 10),
#  ('8', 10),
#  ('rope', 10),
#  ('fire', 10),
#  ('interactive', 10),
#  ('dungeon', 10),
#  ('fight', 10),
#  ('like', 10),
#  ('touch', 10),
#  ('legacy', 10),
#  ('board', 10),
#  ('gif', 10),
#  ('we', 10),
#  ('qr', 10),
#  ('blur', 10),
#  ('european', 10),
#  ('input', 10),
#  ("n't", 10),
#  ('task', 10),
#  ('g', 10),
#  ('transit', 10),
#  ('stickman', 10),
#  ('craigslist', 10),
#  ('san', 10),
#  ('blackjack', 10),
#  ('artificial', 10),
#  ('assault', 10),
#  ('tests', 10),
#  ('defense', 10),
#  ('en', 10),
#  ('dr', 10),
#  ('holdem', 10),
#  ('ch', 10),
#  ('cz', 10),
#  ('pistol', 10),
#  ('charging', 10),
#  ('ew', 10),
#  ('fj', 10),
#  ('hide', 9),
#  ('effect', 9),
#  ('drawing', 9),
#  ('name', 9),
#  ('images', 9),
#  ('state', 9),
#  ('information', 9),
#  ('dmv', 9),
#  ('permit', 9),
#  ('discount', 9),
#  ('complete', 9),
#  ('manual', 9),
#  ('docs', 9),
#  ('plugin', 9),
#  ('meetings', 9),
#  ('tiny', 9),
#  ('accounting', 9),
#  ('tracking', 9),
#  ('professional', 9),
#  ('comic', 9),
#  ('perfect', 9),
#  ('chrome', 9),
#  ('telegram', 9),
#  ('not', 9),
#  ('hot', 9),
#  ('elite', 9),
#  ('just', 9),
#  ('gay', 9),
#  ('numbers', 9),
#  ('girl', 9),
#  ('group', 9),
#  ('vocabulary', 9),
#  ('speak', 9),
#  ('study', 9),
#  ('generator', 9),
#  ('dog', 9),
#  ('channel', 9),
#  ('history', 9),
#  ('budget', 9),
#  ('recipe', 9),
#  ('restaurants', 9),
#  ('body', 9),
#  ('ovulation', 9),
#  ('noise', 9),
#  ('public', 9),
#  ('android™', 9),
#  ('roblox', 9),
#  ('temple', 9),
#  ('plants', 9),
#  ('vs.', 9),
#  ('tiles', 9),
#  ('rush', 9),
#  ('fruit', 9),
#  ('piano', 9),
#  ('cube', 9),
#  ('empire', 9),
#  ('force', 9),
#  ('mlb', 9),
#  ('ice', 9),
#  ('strategy', 9),
#  ('jigsaw', 9),
#  ('rescue', 9),
#  ('crazy', 9),
#  ('jam', 9),
#  ('back', 9),
#  ('adobe', 9),
#  ('mx', 9),
#  ('sport', 9),
#  ('highlights', 9),
#  ('where', 9),
#  ('neon', 9),
#  ('widgets', 9),
#  ('tech', 9),
#  ('commando', 9),
#  ('add-on', 9),
#  ('wizard', 9),
#  ('9.0', 9),
#  ('freddy', 9),
#  ('andreas', 9),
#  ('rifle', 9),
#  ('templates', 9),
#  ('bluetooth', 9),
#  ('church', 9),
#  ('tn', 9),
#  ('dh', 9),
#  ('write', 8),
#  ('men', 8),
#  ('disney', 8),
#  ('net', 8),
#  ('american', 8),
#  ('speedometer', 8),
#  ('mirror', 8),
#  ('discover', 8),
#  ('women', 8),
#  ('medicine', 8),
#  ('services', 8),
#  ('square', 8),
#  ('express', 8),
#  ('children', 8),
#  ('can', 8),
#  ('streaming', 8),
#  ('opera', 8),
#  ('notifier', 8),
#  ('rooms', 8),
#  ('lyrics', 8),
#  ('preschool', 8),
#  ('checker', 8),
#  ('toca', 8),
#  ('motorola', 8),
#  ('champions', 8),
#  ('entertainment', 8),
#  ('show', 8),
#  ('demand', 8),
#  ('series', 8),
#  ('sonic', 8),
#  ('t-mobile', 8),
#  ('stock', 8),
#  ('booking', 8),
#  ('fat', 8),
#  ('lose', 8),
#  ('cycling', 8),
#  ('walking', 8),
#  ('chest', 8),
#  ('plans', 8),
#  ('apartments', 8),
#  ('homes', 8),
#  ('beautiful', 8),
#  ('ruler', 8),
#  ('decorating', 8),
#  ('island', 8),
#  ('wall', 8),
#  ('stickers', 8),
#  ('helper', 8),
#  ('barcode', 8),
#  ('big', 8),
#  ('solitaire', 8),
#  ('salon', 8),
#  ('kick', 8),
#  ('climb', 8),
#  ('farm', 8),
#  ('toy', 8),
#  ('vs', 8),
#  ('stars', 8),
#  ('castle', 8),
#  ('earth', 8),
#  ('dead', 8),
#  ('jewels', 8),
#  ('turbo', 8),
#  ('off', 8),
#  ('4x4', 8),
#  ('build', 8),
#  ('global', 8),
#  ('motocross', 8),
#  ('medical', 8),
#  ('mega', 8),
#  ('drug', 8),
#  ('hearing', 8),
#  ('lab', 8),
#  ('discounts', 8),
#  ('magazine', 8),
#  ('ultra', 8),
#  ('airlines', 8),
#  ('files', 8),
#  ('backup', 8),
#  ('killer', 8),
#  ('podcast', 8),
#  ('what', 8),
#  ('fcu', 8),
#  ('land', 8),
#  ('analog', 8),
#  ('saver', 8),
#  ('gate', 8),
#  ('bacterial', 8),
#  ('vaginosis', 8),
#  ('thailand', 8),
#  ("hold'em", 8),
#  ('dy', 8),
#  ('cool', 7),
#  ('pink', 7),
#  ('plan', 7),
#  ('frames', 7),
#  ('without', 7),
#  ('tax', 7),
#  ('payment', 7),
#  ('handbook', 7),
#  ('grammar', 7),
#  ('solutions', 7),
#  ('jobs', 7),
#  ('curriculum', 7),
#  ('vitae', 7),
#  ('alabama', 7),
#  ('team', 7),
#  ('original', 7),
#  ...]

# %%
numero_documentos = len(apps)
print(numero_documentos)
# Out:
# 10841

# %%
idf = {}
for token in vocabulario.keys():
    idf[token] = np.log(numero_documentos / numero_documentos_termo[token])

# %%
idf
# Out:
# {'photo': 4.191224093837094,
#  'editor': 4.439060257741675,
#  '&': 2.42415723719941,
#  'candy': 6.113036691313346,
#  'camera': 4.439060257741675,
#  'grid': 7.681652609227191,
#  'scrapbook': 9.291090521661292,
#  'coloring': 5.553420903377924,
#  'book': 5.28375733642882,
#  'moana': 8.192478232993182,
#  'u': 5.857103317176145,
#  'launcher': 4.860273722817978,
#  'lite': 5.2306475111148725,
#  '–': 4.335263464060031,
#  'free': 3.0685142535899232,
#  'live': 4.03359514963351,
#  'cool': 7.345180372605978,
#  'themes': 6.113036691313346,
#  ',': 2.9649410485061924,
#  'hide': 7.0938659443250724,
#  'apps': 6.246568083937869,
#  'sketch': 8.192478232993182,
#  '-': 1.9102114860971755,
#  'draw': 6.072214696793091,
#  'paint': 6.806183871873292,
#  'pixel': 5.794582960194812,
#  'number': 5.213553077755573,
#  'art': 5.653504361934906,
#  'paper': 8.597943341101347,
#  'flowers': 7.681652609227191,
#  'instructions': 8.597943341101347,
#  'smoke': 8.597943341101347,
#  'effect': 7.0938659443250724,
#  'maker': 5.147955795269759,
#  'infinite': 9.291090521661292,
#  'painter': 9.291090521661292,
#  'garden': 7.499331052433237,
#  'kids': 4.9736024081249814,
#  'drawing': 7.0938659443250724,
#  'fun': 5.653504361934906,
#  'text': 5.18021665748798,
#  'on': 5.3398468030798645,
#  'fonteee': 9.291090521661292,
#  'name': 7.0938659443250724,
#  'focus': 6.726141164199755,
#  'n': 5.627528875531645,
#  'filters': 6.893195248862921,
#  'tattoo': 8.192478232993182,
#  'my': 4.314356779240717,
#  'mandala': 8.192478232993182,
#  '3d': 4.49529997606455,
#  'color': 5.359264888936966,
#  'by': 4.203494186428908,
#  'sandbox': 6.457877177605075,
#  'learn': 4.599742639432148,
#  'to': 4.618261687199386,
#  'kawaii': 7.904796160541401,
#  'characters': 9.291090521661292,
#  'designer': 7.681652609227191,
#  'write': 7.211648979981456,
#  'your': 5.3398468030798645,
#  'with': 4.627651427549225,
#  'shapes': 8.192478232993182,
#  '350': 9.291090521661292,
#  'diy': 6.726141164199755,
#  'room': 6.400718763765127,
#  'decor': 7.904796160541401,
#  'ideas': 5.995253655656962,
#  'flipaclip': 9.291090521661292,
#  'cartoon': 6.988505428667246,
#  'animation': 9.291090521661292,
#  'ibis': 9.291090521661292,
#  'x': 5.52989040596773,
#  'logo': 7.904796160541401,
#  'small': 7.904796160541401,
#  'business': 6.03299398363981,
#  'boys': 9.291090521661292,
#  'six': 7.499331052433237,
#  'pack': 5.707571583205182,
#  'men': 7.211648979981456,
#  "'s": 4.487069476928035,
#  'suit': 9.291090521661292,
#  'superheroes': 8.192478232993182,
#  'wallpapers': 4.92164266919427,
#  '|': 5.707571583205182,
#  '4k': 6.893195248862921,
#  'backgrounds': 6.583040320559082,
#  'mcqueen': 8.597943341101347,
#  'pages': 6.806183871873292,
#  'hd': 4.7267423301934555,
#  'mickey': 9.291090521661292,
#  'minnie': 9.291090521661292,
#  'harley': 9.291090521661292,
#  'quinn': 9.291090521661292,
#  'colorfit': 9.291090521661292,
#  'animated': 7.904796160541401,
#  'pencil': 8.597943341101347,
#  'easy': 5.794582960194812,
#  'realistic': 8.192478232993182,
#  'tutorial': 6.893195248862921,
#  'pink': 7.345180372605978,
#  'silver': 9.291090521661292,
#  'bow': 9.291090521661292,
#  'keyboard': 5.196745959439191,
#  'theme': 4.439060257741675,
#  'anime': 6.726141164199755,
#  'manga': 6.400718763765127,
#  'origami': 9.291090521661292,
#  'i': 5.196745959439191,
#  'creative': 7.681652609227191,
#  'idea': 8.597943341101347,
#  'how': 6.400718763765127,
#  'ladybug': 7.904796160541401,
#  'and': 3.6634694079706547,
#  'cat': 6.806183871873292,
#  'noir': 7.904796160541401,
#  'unicorn': 7.681652609227191,
#  'floor': 9.291090521661292,
#  'plan': 7.345180372605978,
#  'creator': 6.583040320559082,
#  'pip': 8.597943341101347,
#  'collage': 5.857103317176145,
#  'disney': 7.211648979981456,
#  'princess': 6.583040320559082,
#  'clothes': 8.597943341101347,
#  'fashion': 5.995253655656962,
#  'sad': 8.597943341101347,
#  'poetry': 9.291090521661292,
#  'frames': 7.345180372605978,
#  '2018': 4.363836836504087,
#  'textgram': 8.597943341101347,
#  'photos': 6.113036691313346,
#  'splash': 8.597943341101347,
#  '!': 4.349448099051988,
#  'popsicle': 8.597943341101347,
#  'sticks': 9.291090521661292,
#  'similar': 9.291090521661292,
#  'craft': 6.726141164199755,
#  'canva': 9.291090521661292,
#  ':': 2.3863397516994533,
#  'poster': 9.291090521661292,
#  'banner': 8.597943341101347,
#  'card': 6.2953582481073,
#  'graphic': 9.291090521661292,
#  'design': 6.03299398363981,
#  'install': 9.291090521661292,
#  'images': 7.0938659443250724,
#  'music': 5.602211067547356,
#  'make': 6.893195248862921,
#  'video': 4.070734696582967,
#  'without': 7.345180372605978,
#  'net': 7.211648979981456,
#  'little': 6.2000480683029755,
#  'teddy': 9.291090521661292,
#  'bear': 6.400718763765127,
#  'colouring': 8.597943341101347,
#  'game': 4.423556071205709,
#  'food': 5.627528875531645,
#  'monster': 6.806183871873292,
#  'truck': 5.995253655656962,
#  'stunt': 8.192478232993182,
#  '2019': 6.893195248862921,
#  'real': 5.28375733642882,
#  'tractor': 8.597943341101347,
#  'farming': 7.499331052433237,
#  'ultimate': 6.155596305732142,
#  'f1': 9.291090521661292,
#  'racing': 5.419889510753401,
#  'championship': 8.597943341101347,
#  'used': 6.893195248862921,
#  'cars': 6.072214696793091,
#  'trucks': 6.457877177605075,
#  'for': 2.979355712508377,
#  'sale': 6.652033192046034,
#  'american': 7.211648979981456,
#  'muscle': 7.681652609227191,
#  'car': 5.101435779634866,
#  'race': 6.652033192046034,
#  'offroad': 6.346651542494851,
#  'oil': 8.192478232993182,
#  'tanker': 9.291090521661292,
#  'driver': 6.072214696793091,
#  'transport': 7.499331052433237,
#  'tickets': 6.518501799421511,
#  'sda': 7.904796160541401,
#  'exam': 6.518501799421511,
#  'from': 6.518501799421511,
#  'the': 3.722746017900195,
#  'state': 7.0938659443250724,
#  'traffic': 6.2000480683029755,
#  'safety': 7.681652609227191,
#  'inspectorate': 8.597943341101347,
#  'drom.ru': 9.291090521661292,
#  'gas': 7.681652609227191,
#  'prices': 7.904796160541401,
#  '(': 3.538517882835659,
#  'germany': 8.597943341101347,
#  'only': 7.904796160541401,
#  ')': 3.525899418876447,
#  'extreme': 6.988505428667246,
#  'rally': 8.192478232993182,
#  'restart': 9.291090521661292,
#  'navigator': 6.893195248862921,
#  'reg': 9.291090521661292,
#  'check': 6.893195248862921,
#  'regnumber': 9.291090521661292,
#  'find': 5.794582960194812,
#  'information': 7.0938659443250724,
#  'about': 8.192478232993182,
#  'swedish': 9.291090521661292,
#  'vehicles': 7.904796160541401,
#  'citybus': 9.291090521661292,
#  'lviv': 9.291090521661292,
#  'cdl': 9.291090521661292,
#  'practice': 6.246568083937869,
#  'test': 5.553420903377924,
#  'edition': 6.246568083937869,
#  'ezetc': 9.291090521661292,
#  'etc': 8.597943341101347,
#  'balance': 8.597943341101347,
#  'inquiry': 8.597943341101347,
#  'meter': 6.2953582481073,
#  'trial': 7.904796160541401,
#  'real-time': 7.904796160541401,
#  'vin': 9.291090521661292,
#  'report': 6.652033192046034,
#  'dmv': 7.0938659443250724,
#  'permit': 7.0938659443250724,
#  'vehicle': 8.597943341101347,
#  'tax': 7.345180372605978,
#  'mexico': 7.681652609227191,
#  'ulysse': 8.597943341101347,
#  'speedometer': 7.211648979981456,
#  'repuve': 9.291090521661292,
#  'trovit': 8.597943341101347,
#  'fines': 7.904796160541401,
#  'of': 4.228495488634325,
#  'are': 9.291090521661292,
#  'official': 5.76472999704513,
#  'inspection': 9.291090521661292,
#  'payment': 7.345180372605978,
#  'sk': 8.192478232993182,
#  'enca': 9.291090521661292,
#  'direct': 7.904796160541401,
#  'malls': 9.291090521661292,
#  'search': 5.50690088774303,
#  'android': 4.7912808513310265,
#  'auto': 6.246568083937869,
#  'maps': 5.958886011486088,
#  'media': 7.499331052433237,
#  'messaging': 6.988505428667246,
#  'voice': 6.03299398363981,
#  'pdd-ua': 9.291090521661292,
#  '+': 5.3992702235506655,
#  'rf': 9.291090521661292,
#  'super': 5.50690088774303,
#  'police': 6.806183871873292,
#  'lights': 7.904796160541401,
#  'sirens': 8.597943341101347,
#  'follow': 9.291090521661292,
#  'me': 6.246568083937869,
#  'detector': 6.457877177605075,
#  'speed': 6.246568083937869,
#  'radar': 6.583040320559082,
#  'best': 5.419889510753401,
#  'pda': 9.291090521661292,
#  'pick': 8.597943341101347,
#  'part': 7.904796160541401,
#  'garage': 8.192478232993182,
#  'pakwheels': 9.291090521661292,
#  'buy': 5.857103317176145,
#  'sell': 6.2000480683029755,
#  'supervision': 9.291090521661292,
#  'service': 6.246568083937869,
#  'alert': 7.499331052433237,
#  'goo': 9.291090521661292,
#  'whole': 8.597943341101347,
#  'go': 4.896641366988852,
#  'carmax': 9.291090521661292,
#  'inventory': 7.904796160541401,
#  'sounds': 6.03299398363981,
#  'rst': 9.291090521661292,
#  'pct': 9.291090521661292,
#  'autoscout24': 8.597943341101347,
#  'switzerland': 8.597943341101347,
#  'new': 5.18021665748798,
#  'zona': 9.291090521661292,
#  'azul': 9.291090521661292,
#  'digital': 6.113036691313346,
#  'fácil': 9.291090521661292,
#  'sp': 9.291090521661292,
#  'cet': 9.291090521661292,
#  'são': 9.291090521661292,
#  'paulo': 9.291090521661292,
#  'sms': 6.03299398363981,
#  'park': 6.988505428667246,
#  'skencar': 9.291090521661292,
#  'fuelio': 9.291090521661292,
#  'log': 6.457877177605075,
#  'costs': 9.291090521661292,
#  'is': 7.681652609227191,
#  'first': 6.583040320559082,
#  'purchase': 9.291090521661292,
#  'quotation': 9.291090521661292,
#  'dealer': 8.597943341101347,
#  'all': 5.484428031890972,
#  'parking': 6.518501799421511,
#  'lot': 9.291090521661292,
#  'national': 7.681652609227191,
#  'application': 6.893195248862921,
#  '/': 5.995253655656962,
#  'sharing': 6.893195248862921,
#  'discount': 7.0938659443250724,
#  'debits': 9.291090521661292,
#  'station': 7.904796160541401,
#  'hush': 9.291090521661292,
#  'beauty': 5.602211067547356,
#  'everyone': 8.192478232993182,
#  'ipsy': 9.291090521661292,
#  'makeup': 6.246568083937869,
#  'tips': 6.518501799421511,
#  'natural': 8.597943341101347,
#  'recipes': 6.155596305732142,
#  'bestcam': 9.291090521661292,
#  'selfie-selfie': 9.291090521661292,
#  'mirror': 7.211648979981456,
#  'zoom': 7.499331052433237,
#  'exposure': 8.597943341101347,
#  'selfie': 5.32079860810917,
#  'hairstyles': 7.681652609227191,
#  'step': 6.652033192046034,
#  'tie': 9.291090521661292,
#  'always': 9.291090521661292,
#  'be': 5.857103317176145,
#  'happy': 7.904796160541401,
#  'ulta': 9.291090521661292,
#  'prom': 9.291090521661292,
#  'sweet': 6.806183871873292,
#  'colors': 7.499331052433237,
#  'white': 6.346651542494851,
#  'in': 4.860273722817978,
#  'urdu': 8.192478232993182,
#  'filter': 6.072214696793091,
#  'sticker': 6.893195248862921,
#  'wrinkles': 9.291090521661292,
#  'rejuvenation': 9.291090521661292,
#  'eyes': 7.681652609227191,
#  'girls': 5.857103317176145,
#  'sinhala': 9.291090521661292,
#  'haircut': 9.291090521661292,
#  'tutorials/haircut': 9.291090521661292,
#  'videos': 5.52989040596773,
#  'sephora': 9.291090521661292,
#  'skin': 7.499331052433237,
#  'care': 6.346651542494851,
#  'fragrance': 9.291090521661292,
#  'shop': 5.958886011486088,
#  'manicure': 9.291090521661292,
#  'nail': 8.192478232993182,
#  'b': 5.857103317176145,
#  'facial': 9.291090521661292,
#  'wrinkle': 9.291090521661292,
#  'reduction': 9.291090521661292,
#  'secrets': 9.291090521661292,
#  'youth': 8.597943341101347,
#  'health': 5.995253655656962,
#  'losing': 9.291090521661292,
#  'weight': 6.2000480683029755,
#  'discover': 7.211648979981456,
#  'eyeliner': 9.291090521661292,
#  'dresses': 8.192478232993182,
#  'fashions': 9.291090521661292,
#  '+3000': 9.291090521661292,
#  'lady': 8.597943341101347,
#  'adviser': 9.291090521661292,
#  'women': 7.211648979981456,
#  'rainbow': 8.192478232993182,
#  'methods': 8.597943341101347,
#  'teeth': 8.192478232993182,
#  'whitening': 8.597943341101347,
#  'wattpad': 8.597943341101347,
#  '📖': 8.597943341101347,
#  'books': 6.2953582481073,
#  'e-book': 8.597943341101347,
#  'read': 6.155596305732142,
#  'download': 5.8253546188615655,
#  'green': 7.499331052433237,
#  'wikipedia': 9.291090521661292,
#  'amazon': 6.988505428667246,
#  'kindle': 8.597943341101347,
#  'reader': 5.627528875531645,
#  'dictionary': 5.8253546188615655,
#  'merriam-webster': 8.597943341101347,
#  'nook': 7.681652609227191,
#  'ebooks': 8.192478232993182,
#  'magazines': 7.904796160541401,
#  'panda': 6.155596305732142,
#  'radio': 5.627528875531645,
#  'store': 6.806183871873292,
#  'fbreader': 9.291090521661292,
#  'favorite': 7.904796160541401,
#  'english': 5.014424402645236,
#  'grammar': 7.345180372605978,
#  'complete': 7.0938659443250724,
#  'handbook': 7.345180372605978,
#  'spirit': 9.291090521661292,
#  'fanfiction': 9.291090521661292,
#  'stories': 6.346651542494851,
#  'google': 4.769301944612251,
#  'play': 5.995253655656962,
#  'alreader': 9.291090521661292,
#  '-any': 9.291090521661292,
#  'offline': 5.440942919951233,
#  'oxford': 8.192478232993182,
#  'tagalog': 9.291090521661292,
#  'spanish': 6.988505428667246,
#  'translator': 6.893195248862921,
#  'familysearch': 9.291090521661292,
#  'tree': 8.597943341101347,
#  'cloud': 6.346651542494851,
#  'prophetic': 9.291090521661292,
#  'medicine': 7.211648979981456,
#  'readera': 9.291090521661292,
#  'ebook': 7.499331052433237,
#  'app': 3.501130350764038,
#  'devices': 8.597943341101347,
#  'anonymous': 7.681652609227191,
#  'caller': 6.400718763765127,
#  'detection': 9.291090521661292,
#  'litnet': 9.291090521661292,
#  'e-books': 9.291090521661292,
#  'online': 4.758491028508036,
#  'eboox': 8.597943341101347,
#  'fb2': 8.597943341101347,
#  'epub': 8.597943341101347,
#  'zip': 8.597943341101347,
#  'persian': 8.192478232993182,
#  'flybook': 9.291090521661292,
#  'maths': 8.597943341101347,
#  'formulas': 9.291090521661292,
#  'ancestry': 9.291090521661292,
#  'htc': 6.155596305732142,
#  'help': 6.893195248862921,
#  'translation': 8.597943341101347,
#  'bengali': 8.192478232993182,
#  'pdf': 5.707571583205182,
#  '30': 6.652033192046034,
#  'days': 6.806183871873292,
#  'guideline': 9.291090521661292,
#  'guaranteed': 9.291090521661292,
#  'moon+': 9.291090521661292,
#  'sh-02j': 9.291090521661292,
#  'owner': 9.291090521661292,
#  'manual': 7.0938659443250724,
#  '8.0': 8.192478232993182,
#  'english-myanmar': 9.291090521661292,
#  'golden': 7.499331052433237,
#  'en-ar': 9.291090521661292,
#  'language': 6.726141164199755,
#  'azpen': 9.291090521661292,
#  'ereader': 8.597943341101347,
#  'urbano': 9.291090521661292,
#  'v': 6.072214696793091,
#  '02': 8.597943341101347,
#  'instruction': 9.291090521661292,
#  'visual': 7.499331052433237,
#  'voicemail': 7.904796160541401,
#  'metropcs': 9.291090521661292,
#  'indeed': 9.291090521661292,
#  'job': 6.583040320559082,
#  'uber': 7.681652609227191,
#  'adp': 9.291090521661292,
#  'mobile': 3.8884131397890123,
#  'solutions': 7.345180372605978,
#  'snag': 9.291090521661292,
#  'jobs': 7.345180372605978,
#  'hiring': 9.291090521661292,
#  'now': 5.577518454956984,
#  'docs': 7.0938659443250724,
#  'go™': 8.597943341101347,
#  'office': 6.893195248862921,
#  'suite': 8.597943341101347,
#  'officesuite': 8.192478232993182,
#  'usps': 9.291090521661292,
#  'mobile®': 8.192478232993182,
#  'ziprecruiter': 9.291090521661292,
#  'curriculum': 7.345180372605978,
#  'vitae': 7.345180372605978,
#  'cv': 5.577518454956984,
#  'builder': 5.995253655656962,
#  'resume': 5.8253546188615655,
#  'primer': 8.597943341101347,
#  'alba': 8.597943341101347,
#  'heaven': 9.291090521661292,
#  'alvarez': 9.291090521661292,
#  'portal': 7.681652609227191,
#  'services': 7.211648979981456,
#  'superlivepro': 9.291090521661292,
#  'facebook': 5.794582960194812,
#  'manager': 4.656361533431656,
#  'pro': 4.03359514963351,
#  'space': 6.246568083937869,
#  'employment': 9.291090521661292,
#  'center': 6.806183871873292,
#  'box': 6.806183871873292,
#  'polaris': 7.904796160541401,
#  'lg': 6.583040320559082,
#  'call': 5.379067516233146,
#  'blocker': 6.2000480683029755,
#  'alabama': 7.345180372605978,
#  'square': 7.211648979981456,
#  'point': 6.988505428667246,
#  'pos': 8.597943341101347,
#  'plugin': 7.0938659443250724,
#  'aot': 9.291090521661292,
#  'v5.0': 9.291090521661292,
#  'kariyer.net': 9.291090521661292,
#  'seek': 8.597943341101347,
#  'become': 9.291090521661292,
#  'a': 4.92164266919427,
#  'or': 6.893195248862921,
#  'advertise': 9.291090521661292,
#  'meetings': 7.0938659443250724,
#  'installer': 7.499331052433237,
#  'sd': 8.192478232993182,
#  'ads': 6.400718763765127,
#  'indiamart': 9.291090521661292,
#  'products': 8.192478232993182,
#  'trade': 8.192478232993182,
#  'viettelpost': 9.291090521661292,
#  'express': 7.211648979981456,
#  'delivery': 5.995253655656962,
#  'myasus': 9.291090521661292,
#  'korea': 7.904796160541401,
#  'career': 8.597943341101347,
#  '104': 8.597943341101347,
#  'looking': 9.291090521661292,
#  'part-time': 9.291090521661292,
#  'checkup': 9.291090521661292,
#  'treatment': 7.499331052433237,
#  'myanmar': 7.904796160541401,
#  '2d/3d': 8.597943341101347,
#  'quick': 6.893195248862921,
#  'scanner': 5.76472999704513,
#  'ocr': 8.192478232993182,
#  'sabn': 9.291090521661292,
#  'ati': 9.291090521661292,
#  'cargoes': 9.291090521661292,
#  'transportation': 8.597943341101347,
#  'secure': 6.155596305732142,
#  'folder': 9.291090521661292,
#  'ups': 9.291090521661292,
#  'y': 6.893195248862921,
#  'menu': 9.291090521661292,
#  'signeasy': 8.597943341101347,
#  'sign': 8.192478232993182,
#  'fill': 7.499331052433237,
#  'other': 7.904796160541401,
#  'documents': 7.904796160541401,
#  'genius': 7.681652609227191,
#  'scan': 6.246568083937869,
#  'tiny': 7.0938659443250724,
#  'fast': 5.2306475111148725,
#  'doc': 7.681652609227191,
#  'mdscan': 8.597943341101347,
#  'turboscan': 8.597943341101347,
#  'receipts': 7.499331052433237,
#  'zenefits': 8.597943341101347,
#  'slack': 8.192478232993182,
#  'freshbooks': 8.597943341101347,
#  'classic': 5.735742460171878,
#  'insightly': 8.597943341101347,
#  'crm': 8.192478232993182,
#  'quickbooks': 7.904796160541401,
#  'accounting': 7.0938659443250724,
#  'invoicing': 8.192478232993182,
#  'expenses': 7.499331052433237,
#  'hipchat': 8.192478232993182,
#  'chat': 4.161191806738218,
#  'built': 8.597943341101347,
#  'teams': 8.192478232993182,
#  'xero': 8.597943341101347,
#  'software': 8.192478232993182,
#  'mailchimp': 8.597943341101347,
#  'email': 6.988505428667246,
#  'marketing': 7.904796160541401,
#  'automation': 8.192478232993182,
#  'crew': 8.192478232993182,
#  'scheduling': 8.597943341101347,
#  'asana': 8.597943341101347,
#  'organize': 8.192478232993182,
#  'team': 7.345180372605978,
#  'projects': 8.597943341101347,
#  'analytics': 7.904796160541401,
#  'adwords': 8.597943341101347,
#  'zoho': 7.681652609227191,
#  'invoice': 7.681652609227191,
#  'time': 5.857103317176145,
#  'tracking': 7.0938659443250724,
#  'join.me': 8.192478232993182,
#  'simple': 6.246568083937869,
#  '2go': 8.597943341101347,
#  '—': 6.518501799421511,
#  'professional': 7.0938659443250724,
#  'invoices': 8.597943341101347,
#  'estimates': 8.597943341101347,
#  'cisco': 8.597943341101347,
#  'webex': 8.597943341101347,
#  'screenmeet': 9.291090521661292,
#  '.': 4.716379543157909,
#  'phone': 5.50690088774303,
#  'meeting': 8.597943341101347,
#  'microsoft': 6.113036691313346,
#  'remote': 5.28375733642882,
#  'desktop': 9.291090521661292,
#  'start': 8.597943341101347,
#  'clickmeeting': 9.291090521661292,
#  'webinars': 8.597943341101347,
#  'bluejeans': 9.291090521661292,
#  'skype': 7.681652609227191,
#  'verify': 9.291090521661292,
#  'line': 6.518501799421511,
#  'webtoon': 7.681652609227191,
#  'comics': 6.2000480683029755,
#  'master': 6.346651542494851,
#  'comic': 7.0938659443250724,
#  'ganma': 9.291090521661292,
#  'original': 7.345180372605978,
#  'charge': 8.192478232993182,
#  'röhrich': 9.291090521661292,
#  'werner': 9.291090521661292,
#  'soundboard': 7.499331052433237,
#  'pokez': 9.291090521661292,
#  'mangatoon': 9.291090521661292,
#  'updated': 8.192478232993182,
#  'daily': 5.653504361934906,
#  'rock': 8.192478232993182,
#  'thai': 7.904796160541401,
#  'vietnam': 8.192478232993182,
#  'story': 6.246568083937869,
#  'dragon': 6.03299398363981,
#  'ball': 6.457877177605075,
#  'wallpaper': 5.056984017064032,
#  'ringtones': 6.2953582481073,
#  'funny': 6.155596305732142,
#  'jokes': 7.345180372605978,
#  'truyện': 9.291090521661292,
#  'vui': 8.597943341101347,
#  'tý': 9.291090521661292,
#  'quậy': 9.291090521661292,
#  'es': 5.680172609017068,
#  'shojo': 9.291090521661292,
#  'love': 5.50690088774303,
#  '♪': 9.291090521661292,
#  'comico': 9.291090521661292,
#  'popular': 7.904796160541401,
#  'everyday': 8.597943341101347,
#  '漫咖': 9.291090521661292,
#  'novel': 7.904796160541401,
#  'emmanuella': 8.597943341101347,
#  'dc': 5.707571583205182,
#  'zero': 7.904796160541401,
#  'japanese': 8.192478232993182,
#  'marvel': 6.893195248862921,
#  'unlimited': 6.893195248862921,
#  'tapas': 9.291090521661292,
#  'novels': 8.192478232993182,
#  'children': 7.211648979981456,
#  'cartoons': 7.681652609227191,
#  'mithu-mina-raju': 9.291090521661292,
#  'narrator': 9.291090521661292,
#  '【ranobbe': 9.291090521661292,
#  'free】': 9.291090521661292,
#  'novelba': 9.291090521661292,
#  'that': 7.499331052433237,
#  'you': 6.155596305732142,
#  'can': 7.211648979981456,
#  'faustop': 9.291090521661292,
#  'mania': 7.499331052433237,
#  'az': 6.113036691313346,
#  'buff': 9.291090521661292,
#  'thun': 9.291090521661292,
#  'web': 6.246568083937869,
#  'fiction': 8.597943341101347,
#  'mini': 6.072214696793091,
#  'pixiv': 8.597943341101347,
#  'hojiboy': 9.291090521661292,
#  'tojiboyev': 9.291090521661292,
#  'life': 5.8253546188615655,
#  'hacks': 9.291090521661292,
#  'perfect': 7.0938659443250724,
#  'viewer': 6.346651542494851,
#  '100,000+': 8.192478232993182,
#  'think': 8.597943341101347,
#  'memes': 7.681652609227191,
#  'button': 7.681652609227191,
#  'laftel': 9.291090521661292,
#  'watching': 9.291090521661292,
#  'announcing': 9.291090521661292,
#  'snooping': 9.291090521661292,
#  'streaming': 7.211648979981456,
#  'messenger': 5.577518454956984,
#  'whatsapp': 6.246568083937869,
#  'chrome': 7.0938659443250724,
#  'calls': 5.3992702235506655,
#  'messages': 6.518501799421511,
#  'gmail': 7.681652609227191,
#  'hangouts': 7.499331052433237,
#  'viber': 7.681652609227191,
#  'tele2': 9.291090521661292,
#  'firefox': 7.499331052433237,
#  'browser': 5.0715828164851855,
#  'private': 6.2000480683029755,
#  'yahoo': 6.583040320559082,
#  'mail': 6.346651542494851,
#  'stay': 7.681652609227191,
#  'organized': 8.192478232993182,
#  'imo': 7.345180372605978,
#  'beta': 6.806183871873292,
#  'contacts': 6.806183871873292,
#  'explorer': 6.155596305732142,
#  'opera': 7.211648979981456,
#  '4g': 8.192478232993182,
#  'megafon': 9.291090521661292,
#  'dashboard': 8.192478232993182,
#  'zenui': 7.499331052433237,
#  'dialer': 6.583040320559082,
#  'cricket': 7.681652609227191,
#  'tracfone': 9.291090521661292,
#  'account': 7.499331052433237,
#  'privacy': 6.806183871873292,
#  'dev': 8.597943341101347,
#  'xperia': 7.499331052433237,
#  'link™': 9.291090521661292,
#  'touchpal': 8.192478232993182,
#  'emoji': 6.246568083937869,
#  'who': 6.988505428667246,
#  'wechat': 7.904796160541401,
#  'uc': 7.345180372605978,
#  '-tiny': 8.192478232993182,
#  'magenta': 9.291090521661292,
#  'telegram': 7.0938659443250724,
#  'duo': 8.597943341101347,
#  'high': 6.893195248862921,
#  'quality': 7.499331052433237,
#  'puffin': 7.681652609227191,
#  'seznam.cz': 9.291090521661292,
#  'antillean': 9.291090521661292,
#  'gold': 6.2953582481073,
#  'version': 7.681652609227191,
#  'at': 5.2306475111148725,
#  't': 6.113036691313346,
#  'gmx': 9.291090521661292,
#  'omlet': 8.597943341101347,
#  'vodacom': 9.291090521661292,
#  'sa': 7.904796160541401,
#  'edge': 8.597943341101347,
#  'phones': 7.904796160541401,
#  'talkatone': 8.597943341101347,
#  'texts': 7.345180372605978,
#  'mo+': 8.597943341101347,
#  'im': 8.192478232993182,
#  'messaging+': 9.291090521661292,
#  'mms': 8.597943341101347,
#  'chomp': 9.291090521661292,
#  'glide': 8.597943341101347,
#  'allo': 8.192478232993182,
#  'talkray': 8.597943341101347,
#  'groupme': 9.291090521661292,
#  'mysms': 9.291090521661292,
#  'sync': 7.904796160541401,
#  'bbm': 8.192478232993182,
#  'kakaotalk': 8.192478232993182,
#  '2ndline': 9.291090521661292,
#  'second': 7.681652609227191,
#  'cm': 5.577518454956984,
#  'ad': 5.76472999704513,
#  'ninesky': 9.291090521661292,
#  'dolphin': 8.192478232993182,
#  'adblock🐬': 9.291090521661292,
#  'ghostery': 9.291090521661292,
#  'inbrowser': 9.291090521661292,
#  'incognito': 9.291090521661292,
#  'browsing': 9.291090521661292,
#  'du': 5.707571583205182,
#  'browser—browse': 8.597943341101347,
#  'lightning': 8.597943341101347,
#  'contacts+': 9.291090521661292,
#  'exdialer': 8.597943341101347,
#  'gtalk': 9.291090521661292,
#  'safest': 9.291090521661292,
#  'full': 5.735742460171878,
#  'screen': 5.440942919951233,
#  'id': 6.346651542494851,
#  'hiya': 9.291090521661292,
#  'block': 5.8253546188615655,
#  'mr.': 9.291090521661292,
#  'number-block': 9.291090521661292,
#  'spam': 8.192478232993182,
#  'should': 9.291090521661292,
#  'answer': 9.291090521661292,
#  '?': 5.627528875531645,
#  'rocketdial': 9.291090521661292,
#  'callapp': 8.597943341101347,
#  'recorder': 5.958886011486088,
#  'whoscall': 8.597943341101347,
#  'cia': 9.291090521661292,
#  'blacklist': 8.192478232993182,
#  'control': 5.707571583205182,
#  'true': 7.499331052433237,
#  'contact': 8.597943341101347,
#  'sync.me': 9.291090521661292,
#  'burner': 8.597943341101347,
#  'truecaller': 8.597943341101347,
#  'blocking': 8.597943341101347,
#  'k-9': 8.597943341101347,
#  'mymail': 9.291090521661292,
#  'hotmail': 9.291090521661292,
#  'outlook': 7.904796160541401,
#  'typeapp': 9.291090521661292,
#  'providers': 9.291090521661292,
#  'newton': 9.291090521661292,
#  'imap': 9.291090521661292,
#  'notifier': 7.211648979981456,
#  'mail.ru': 9.291090521661292,
#  'mail1click': 9.291090521661292,
#  'daum': 9.291090521661292,
#  'next': 6.806183871873292,
#  'mail.com': 9.291090521661292,
#  'solmail': 9.291090521661292,
#  'all-in-one': 7.499331052433237,
#  'vonage': 9.291090521661292,
#  'justalk': 9.291090521661292,
#  'moco+': 8.597943341101347,
#  'meet': 5.265738830926143,
#  'people': 5.995253655656962,
#  'calculator': 4.685920335673201,
#  'truth': 8.597943341101347,
#  'dare': 8.597943341101347,
#  'dating': 4.3932507217103804,
#  'app-': 9.291090521661292,
#  'blue': 6.806183871873292,
#  'privacyhider': 8.192478232993182,
#  'sayhi': 7.904796160541401,
#  'ambw': 9.291090521661292,
#  'asian': 7.681652609227191,
#  'black': 6.03299398363981,
#  'interracial': 7.681652609227191,
#  'zoosk': 8.597943341101347,
#  'singles': 5.8253546188615655,
#  'okcupid': 8.192478232993182,
#  'match™': 9.291090521661292,
#  'hily': 8.192478232993182,
#  'match': 5.8898931399991366,
#  'hook': 7.681652609227191,
#  'up': 5.857103317176145,
#  'hinge': 8.597943341101347,
#  'relationships': 7.904796160541401,
#  'casual': 8.192478232993182,
#  'adult': 6.893195248862921,
#  'joyride': 7.681652609227191,
#  'bbw': 7.345180372605978,
#  'plus': 5.52989040596773,
#  'size': 7.681652609227191,
#  'moco': 8.192478232993182,
#  'cmb': 8.597943341101347,
#  'hot': 7.0938659443250724,
#  'not': 7.0938659443250724,
#  'someone': 8.192478232993182,
#  'right': 7.681652609227191,
#  'eharmony': 9.291090521661292,
#  'flirt': 6.518501799421511,
#  'chispa': 8.597943341101347,
#  'latino': 8.597943341101347,
#  'latina': 8.597943341101347,
#  'clover': 8.597943341101347,
#  'date': 6.457877177605075,
#  'mingle2': 9.291090521661292,
#  'rooms': 7.211648979981456,
#  'cheers': 9.291090521661292,
#  'stranger': 7.904796160541401,
#  'blendr': 8.597943341101347,
#  'youlove': 8.597943341101347,
#  'premium': 5.995253655656962,
#  'once': 8.192478232993182,
#  'matches': 8.597943341101347,
#  'every': 8.192478232993182,
#  'day': 5.8898931399991366,
#  'blk': 9.291090521661292,
#  'swipe': 9.291090521661292,
#  'cougar': 8.597943341101347,
#  'older': 8.597943341101347,
#  'sugar': 6.806183871873292,
#  'mummy': 8.597943341101347,
#  'howlr': 8.597943341101347,
#  'choice': 7.904796160541401,
#  'randochat': 9.291090521661292,
#  'roulette': 8.597943341101347,
#  'bewild': 9.291090521661292,
#  'fastmeet': 8.597943341101347,
#  'yocutie': 8.597943341101347,
#  'ourtime': 9.291090521661292,
#  '50+': 8.597943341101347,
#  'farmersonly': 8.597943341101347,
#  '50': 7.499331052433237,
#  'mature': 8.597943341101347,
#  'finally': 8.597943341101347,
#  'sudy': 7.904796160541401,
#  'elite': 7.0938659443250724,
#  'rich': 6.155596305732142,
#  'single': 7.345180372605978,
#  'christian': 7.681652609227191,
#  'just': 7.0938659443250724,
#  'she': 7.904796160541401,
#  'top': 6.2953582481073,
#  'lesbian': 7.681652609227191,
#  'parent': 9.291090521661292,
#  '#': 6.457877177605075,
#  '1': 5.857103317176145,
#  'elitesingles': 8.597943341101347,
#  'professionals': 8.192478232993182,
#  'millionaire': 7.681652609227191,
#  'interracialcupid': 9.291090521661292,
#  'mommas': 9.291090521661292,
#  'safe': 6.988505428667246,
#  'muzmatch': 8.192478232993182,
#  'muslim': 7.681652609227191,
#  'arab': 7.904796160541401,
#  'marriage': 8.192478232993182,
#  'nobuffdating': 9.291090521661292,
#  'daddy': 8.192478232993182,
#  'dirty': 7.681652609227191,
#  'emojis': 7.904796160541401,
#  'local': 6.072214696793091,
#  'meet4u': 8.597943341101347,
#  'snpcupid': 9.291090521661292,
#  'avatars': 8.597943341101347,
#  'galaxy': 6.246568083937869,
#  'adultfinder': 9.291090521661292,
#  'gay': 7.0938659443250724,
#  'hookup': 8.597943341101347,
#  'meet24': 8.597943341101347,
#  'bbwcupid': 9.291090521661292,
#  'chatvideo': 9.291090521661292,
#  'trydate': 9.291090521661292,
#  'adults': 7.904796160541401,
#  'usa': 7.345180372605978,
#  'flirtchat': 8.597943341101347,
#  '♥free': 8.597943341101347,
#  'dating/flirting': 8.597943341101347,
#  'app♥': 8.597943341101347,
#  'league': 6.726141164199755,
#  'herpes': 8.597943341101347,
#  '1,000k+': 9.291090521661292,
#  'heart': 6.583040320559082,
#  'mill': 9.291090521661292,
#  '95live': 8.597943341101347,
#  '-sg': 8.597943341101347,
#  'mutual': 8.192478232993182,
#  'lds': 9.291090521661292,
#  '2redbeans': 9.291090521661292,
#  'sweetring': 9.291090521661292,
#  'biggercity': 9.291090521661292,
#  'bears': 7.681652609227191,
#  'chubs': 9.291090521661292,
#  'chasers': 9.291090521661292,
#  'silversingles': 9.291090521661292,
#  'positive': 9.291090521661292,
#  'glam': 8.597943341101347,
#  'idates': 9.291090521661292,
#  'chats': 7.499331052433237,
#  'flirts': 9.291090521661292,
#  'relations': 9.291090521661292,
#  'justdating': 9.291090521661292,
#  'russian': 9.291090521661292,
#  'speaking': 8.192478232993182,
#  'rusdate': 9.291090521661292,
#  'sky': 7.345180372605978,
#  'spi': 9.291090521661292,
#  'blind': 8.192478232993182,
#  'through': 8.192478232993182,
#  'authentication': 8.597943341101347,
#  'seoul': 9.291090521661292,
#  'university': 7.499331052433237,
#  'mi': 7.904796160541401,
#  'hunnam': 9.291090521661292,
#  'hunting': 7.499331052433237,
#  'mingle': 8.597943341101347,
#  'curvy': 8.597943341101347,
#  'chat-': 8.597943341101347,
#  'largefriends': 8.597943341101347,
#  'hitwe': 9.291090521661292,
#  'hundred': 9.291090521661292,
#  'justsayhi-': 9.291090521661292,
#  'nearby': 7.904796160541401,
#  'ferzu': 9.291090521661292,
#  'furries': 9.291090521661292,
#  'social': 6.457877177605075,
#  'network': 6.2953582481073,
#  'wannameet': 9.291090521661292,
#  ...}

# %% [markdown]
# ## IDF é global para o dataset! TF depende de cada documento

# %% [markdown]
# # Agora TF-IDF

# %% [markdown]
# ### primeiro define-se um índice para cada termo

# %%
token2int = {}
indice = 0
for token in vocabulario.keys():
    token2int[token] = indice
    indice += 1

# %% [markdown]
# ### então faz o TF e depois o TF-IDF de cada documento

# %%
tfs = {}
for i in range(len(apps)):  # i é o índice da linha na tabela   
    tf = np.zeros((len(vocabulario)))  # Criand um vetor de zeros do tamanho do vocabulário
    tokens_nome = word_tokenize(apps.iloc[i]['App'].lower())  # Tokenizando o nome do app da linha i
    for token in tokens_nome:
        try:
            tf[token2int[token]] += 1
        except KeyError:
            # Caso o token não exista, não faz nada
            # Se nenhum token do documento for reconhecido, ele será representado por um vetor que contém apenas zeros
            pass
    tf = tf / len(tokens_nome)  # Normalizando por meio da divisão pela quantidade de termos no nome do app
    tfs[i] = tf

# %%
indice_app = 988  # Mude o índice
print("Nome:", apps.iloc[i]['App'])
print(tfs[indice_app])
# Out:
# Nome: iHoroscope - 2018 Daily Horoscope & Astrology
# [0.         0.         0.14285714 ... 0.         0.         0.        ]

# %%
tf_idfs = np.zeros((len(apps), len(vocabulario)))
for i in range(len(apps)):
    tokens_nome = word_tokenize(apps.iloc[i]['App'].lower())
    for token in list(set(tokens_nome)):
        tf_idfs[i][token2int[token]] = tfs[i][token2int[token]] * idf[token]  # TF * IDF

# %%
tf_idfs[988]
# Out:
# array([0.        , 0.        , 0.34630818, ..., 0.        , 0.        ,
#        0.        ])

# %%
tfs[0]
# Out:
# array([0.11111111, 0.11111111, 0.33333333, ..., 0.        , 0.        ,
#        0.        ])

# %%
tf_idfs[0]
# Out:
# array([0.46569157, 0.49322892, 0.80805241, ..., 0.        , 0.        ,
#        0.        ])

# %%
def documento2tfidf(documento):
    # Transforma um documento textual na sua forma baf-of-words com TF-IDF
    tf = np.zeros((len(vocabulario)))
    tokens = word_tokenize(documento.lower())
    for token in tokens:
        try:
            tf[token2int[token]] += 1
        except KeyError:
            pass
    tf = tf / len(tokens)
    tf_idf = np.zeros(len(vocabulario))
    for token in list(set(tokens)):
        try:
            tf_idf[token2int[token]] = tf[token2int[token]] * idf[token]
        except KeyError:
            pass
    return tf_idf
        
def mais_similares(documento, n=5):
    # Retorna os n documentos mais similares ao passado como parâmetro
    tf_idf_documento = documento2tfidf(documento)
    distancias = {}
    for i in range(len(tf_idfs)):
        # Calcula-se a distância entre o documento e todos os nomes dos apps
        distancias[i] = distance.cosine(tf_idf_documento, tf_idfs[i])  # distância cossenoidal
    distancias = sorted(distancias.items(), key=lambda kv: kv[1])  # Ordenando os índices dos apps conforme a distância
    for tupla in distancias[:n]:  # imprime os n mais próximos
        # tupla = (indice_documento, distancia_cossenoidal)
        print("Distância: ", str(tupla[1]), "\nApp: ", apps.iloc[tupla[0]]['App'], "\n")

# %%
mais_similares('Tower Defense')
# Out:
# Distância:  0.509629700339586
# App:  Zombie Defense
#
# Distância:  0.5221367489624491
# App:  DS Tower Defence
#
# Distância:  0.5297371192910412
# App:  Galaxy Defense
#
# Distância:  0.5573500339255162
# App:  Tiny Defense
#
# Distância:  0.5755472407662653
# App:  Treasure Defense

# %%
mais_similares('Trading Card Game')
# Out:
# Distância:  0.46821441292089416
# App:  WIZARD Card Game
#
# Distância:  0.5376848524654655
# App:  BJ card game blackjack
#
# Distância:  0.5740374406692349
# App:  DG Card
#
# Distância:  0.5758557515921419
# App:  NSE Mobile Trading
#
# Distância:  0.6383839664420554
# App:  BlackJack -21 Casino Card Game

# %%
mais_similares('RPG Castle')
# Out:
# Distância:  0.4122705967063145
# App:  Castle Clash: RPG War and Strategy FR
#
# Distância:  0.5118628314988636
# App:  Castle Defense 2
#
# Distância:  0.5809304869798754
# App:  DB for Hustle Castle
#
# Distância:  0.5985022616210119
# App:  Castle Defense : Invasion
#
# Distância:  0.644061338595386
# App:  Hustle Castle: Fantasy Kingdom

# %%
mais_similares('Dolphin')
# Out:
# Distância:  0.3087119463713883
# App:  Cute Dolphin Keyboard
#
# Distância:  0.4232680740837137
# App:  Dolphin and fish coloring book
#
# Distância:  0.49509751146249337
# App:  Dolphin Browser - Fast, Private & Adblock🐬
#
# Distância:  1.0
# App:  Photo Editor & Candy Camera & Grid & ScrapBook
#
# Distância:  1.0
# App:  Coloring book moana

# %%
mais_similares('asdasd')
# Out:
# c:\users\rafae\envs\data_science\lib\site-packages\scipy\spatial\distance.py:702: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# Distância:  nan
# App:  Photo Editor & Candy Camera & Grid & ScrapBook
#
# Distância:  nan
# App:  Coloring book moana
#
# Distância:  nan
# App:  U Launcher Lite – FREE Live Cool Themes, Hide Apps
#
# Distância:  nan
# App:  Sketch - Draw & Paint
#
# Distância:  nan
# App:  Pixel Draw - Number Art Coloring Book

# %% [markdown]
# # Salvando

# %%
import pickle

# %%
def save_obj(obj, name ):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
save_obj(token2int, "token2int")
np.save("tf_idfs.npy", tf_idfs)

# %% [markdown]
# # Checando proximidade com nomes de apps escolhidos aleatoriamente

# %%
indices = np.array(range(len(apps)))
np.random.shuffle(indices)
for indice in indices[:5]:
    print(apps.iloc[indice]['App'], "\n")
    mais_similares(apps.iloc[indice]['App'].lower())
    print("\n------------------------------------\n")
# Out:
# Digital TV
#
# Distância:  0.0
# App:  Digital TV
#
# Distância:  0.5427507089447556
# App:  Mobile TV
#
# Distância:  0.5506188794816429
# App:  Digital Alarm Clock
#
# Distância:  0.560171762726075
# App:  Digital Falak
#
# Distância:  0.5679588940746
# App:  Digital Clock AW-7
#
#
# ------------------------------------
#
# MyASUS - Service Center
#
# Distância:  0.0
# App:  MyASUS - Service Center
#
# Distância:  0.6451397761622895
# App:  My EF Center
#
# Distância:  0.6606582043526472
# App:  BP Service
#
# Distância:  0.6810041397180565
# App:  AQ Service
#
# Distância:  0.7067503682172188
# App:  DV Car Service
#
#
# ------------------------------------
#
# Archery Physics Objects Destruction Apple shooter
#
# Distância:  0.0
# App:  Archery Physics Objects Destruction Apple shooter
#
# Distância:  0.5981787181244416
# App:  Apple Daily Apple News
#
# Distância:  0.6766531066371648
# App:  Creative Destruction
#
# Distância:  0.7784323782022134
# App:  R. Physics Puzzle Game
#
# Distância:  0.7990315905798748
# App:  CK-12 Physics Simulations
#
#
# ------------------------------------
#
# BW Wallpaper
#
# Distância:  0.0
# App:  BW Wallpaper
#
# Distância:  0.34445203450467443
# App:  Wallpaper
#
# Distância:  0.35275143596044545
# App:  BW App
#
# Distância:  0.4442561764768712
# App:  BW Smart
#
# Distância:  0.4772176471077244
# App:  Bw Events
#
#
# ------------------------------------
#
# AX Video Player
#
# Distância:  0.0
# App:  AX Video Player
#
# Distância:  0.22607270315592076
# App:  AX Player -Nougat Video Player
#
# Distância:  0.2862740254950038
# App:  video player
#
# Distância:  0.4145591906597944
# App:  HD Video Player
#
# Distância:  0.45143950557874823
# App:  video player for android
#
#
# ------------------------------------
